# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from utils import MyTabNetClassifier
from acv_explainers.utils import *
from ares import AReS
from cet import CounterfactualExplanationTree
from ce import ActionExtractor
from utils import DatasetHelper, submodular_picking, DATASETS_NAME
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

seed = 2022
np.random.seed(0)

# %%
# Load breast cancer dataset

X, y = load_breast_cancer(return_X_y=True, as_frame=True)
X_tr, X_ts, y_tr, y_ts = train_test_split(X, y, test_size=0.20, random_state=seed)

# %%
# Train Isolation for outlier score

from sklearn.ensemble import IsolationForest

isolation = IsolationForest()
isolation.fit(X_tr)
# Out:
# IsolationForest()

# %%
# Train the model to explain

mdl = LGBMClassifier(n_estimators=50, num_leaves=8)
mdl.fit(X_tr, y_tr)
# Out:
# LGBMClassifier(n_estimators=50, num_leaves=8)

# %%
feature_names = [col.replace(' ', '') for col in X_tr.columns]
feature_names
# Out:
# ['meanradius',
#  'meantexture',
#  'meanperimeter',
#  'meanarea',
#  'meansmoothness',
#  'meancompactness',
#  'meanconcavity',
#  'meanconcavepoints',
#  'meansymmetry',
#  'meanfractaldimension',
#  'radiuserror',
#  'textureerror',
#  'perimetererror',
#  'areaerror',
#  'smoothnesserror',
#  'compactnesserror',
#  'concavityerror',
#  'concavepointserror',
#  'symmetryerror',
#  'fractaldimensionerror',
#  'worstradius',
#  'worsttexture',
#  'worstperimeter',
#  'worstarea',
#  'worstsmoothness',
#  'worstcompactness',
#  'worstconcavity',
#  'worstconcavepoints',
#  'worstsymmetry',
#  'worstfractaldimension']

# %%
target_name = 'Cancer'
target_labels = ['Good', 'Bad']

# %%
feature_constraints = ['' for i in range(len(feature_names))]
len(feature_constraints) == X_tr.shape[1]
# Out:
# True

# %%
feature_categories = []

# %%
feature_types = ['C' for i in range(len(feature_names))]

# %%
X_tr = X_tr.values
X_ts = X_ts.values

# %%
y_tr = y_tr.values
y_ts = y_ts.values

# %%
X = X_tr[mdl.predict(X_tr)==1]
X_vl = X_ts[mdl.predict(X_ts)==1]

# %% [markdown]
# ## Actionable Recourse Summary

# %%
print('## Actionable Recourse Summary')
ares = AReS(mdl, X_tr, max_rule=4, max_rule_length=4, discretization_bins=10, minimum_support=0.05, print_objective=False,
            feature_names=feature_names, feature_types=feature_types, feature_categories=feature_categories, 
            feature_constraints=feature_constraints, target_name=target_name, target_labels=target_labels)
ares = ares.fit(X, max_change_num=4, cost_type='MPS', lambda_acc=1.0, lambda_cov=1.0, lambda_cst=1.0)
print('* Parameters:')
print('\t* lambda_acc: {}'.format(ares.lambda_acc)); print('\t* lambda_cov: {}'.format(ares.lambda_cov)); print('\t* lambda_cst: {}'.format(ares.lambda_cst));
print('\t* minimum support: {}'.format(ares.rule_miner_.minsup_)); print('\t* discretization bins: {}'.format(ares.rule_miner_.fd_.bins)); print('\t* pre-processing time[s]: {}'.format(ares.preprocess_time_)); 
print('\t* max rule: {}'.format(ares.max_rule_)); print('\t* max rule length: {}'.format(ares.max_rule_length_)); print('\t* Time[s]:', ares.time_); 
print('\t* uncover test: {}'.format(ares.uncover(X_vl))); print('\t* conflict: {}'.format(ares.conflict(X_vl))); print();
print('### Learned AReS')
print(ares.to_markdown())
# Out:
# ## Actionable Recourse Summary
# * Parameters:
# 	* lambda_acc: 1.0
# 	* lambda_cov: 1.0
# 	* lambda_cst: 1.0
# 	* minimum support: 0.05
# 	* discretization bins: 10
# 	* pre-processing time[s]: 0.41532748501049355
# 	* max rule: 4
# 	* max rule length: 4
# 	* Time[s]: 276.7805148810003
# 	* uncover test: 0.6764705882352942
# 	* conflict: 0.0
#
# ### Learned AReS
# | | Rule | Action |
# | :---: | --- | --- |
# | Recourse <br> rule 1 <br> (probability: 11.4%) | If 'meanradius<10.21' <br> AND 'worstradius<11.16' <br> AND 'worstperimeter<71.83' <br> AND 'worstarea<380.4' | meanradius>=19.55 <br> AND worstradius>=23.93 <br> AND worstperimeter>=159.8 <br> AND worstarea>=1.72e+03 |
# | Recourse <br> rule 2 <br> (probability: 4.2%) | If '16.34<=worstradius<17.74' <br> AND '108.5<=worstperimeter<118.1' <br> AND '812.3<=worstarea<971.7' | 20.4<=worstradius<23.93 <br> AND 136.6<=worstperimeter<159.8 <br> AND 1.293e+03<=worstarea<1.72e+03 |
# | Recourse <br> rule 3 <br> (probability: 7.3%) | If '14.48<=worstradius<15.34' <br> AND '95.11<=worstperimeter<100.9' <br> AND '637.7<=worstarea<719.5' | 20.4<=worstradius<23.93 <br> AND 136.6<=worstperimeter<159.8 <br> AND 1.293e+03<=worstarea<1.72e+03 |
# | Recourse <br> rule 4 <br> (probability: 5.9%) | If '15.34<=worstradius<16.34' <br> AND '100.9<=worstperimeter<108.5' | 20.4<=worstradius<23.93 <br> AND 136.6<=worstperimeter<159.8 |
# | Default <br> rule | Else | areaerror>=93.81 <br> AND worstradius>=23.93 <br> AND worstperimeter>=159.8 <br> AND worstarea>=1.72e+03 |

# %%
x_ares = ares.predict(X_vl) + X_vl
y_ares = mdl.predict(x_ares)

print('Positve accuracy of AReS = {}'.format(np.mean(y_ares != mdl.predict(X_vl))))
print('Positve Oulier AReS = {}'.format(np.mean(isolation.predict(x_ares) == 1)))
# Out:
# Positve accuracy of AReS = 0.6323529411764706
# Positve Oulier AReS = 0.8235294117647058

# %%
print('Sparsity', np.mean(np.sum(x_ares-X_vl!=0, axis=1)))
# Out:
# Sparsity 3.764705882352941

# %% [markdown]
# # Counterfactual TREE

# %% [markdown]
# ### 1- CET All

# %%
LAMBDA = 0.01
GAMMA = 1.0

print('## Counterfactual Explanation Tree')
cet = CounterfactualExplanationTree(mdl, X_tr, y_tr, max_iteration=500, lime_approximation=False,
                                    feature_names=feature_names, feature_types=feature_types, feature_categories=feature_categories,
                                    feature_constraints=feature_constraints, target_name=target_name, target_labels=target_labels)

cet = cet.fit(X, max_change_num=8, cost_type='MPS', C=LAMBDA, gamma=GAMMA, max_leaf_size=-1, time_limit=180, verbose=True)
print('* Parameters:'); print('\t* lambda: {}'.format(cet.lambda_)); print('\t* gamma: {}'.format(cet.gamma_)); print('\t* max_iteration: {}'.format(cet.max_iteration_));
print('\t* leaf size bound:', cet.leaf_size_bound_); print('\t* leaf size:', cet.n_leaves_); print('\t* LIME approximation:', cet.lime_approximation_); print('\t* Time[s]:', cet.time_); print();
print('### Learned CET')
cet.print_tree()
# Out:
# ## Counterfactual Explanation Tree
# ## Stochastic Local Searching ...
# ### Iteration: 10
# #### Before:
# - If meanfractaldimension<0.0676:
# 	- If compactnesserror<0.0117:
# 		* Action [Cancer: Bad -> Good] (74/74 = 100.0% / MeanCost = 0.738):
# 			* meanradius: +10.2081
# 			* radiuserror: +2.3715
# 			* areaerror: +501.1211
# 			* worstradius: +16.6584
# 			* worsttexture: +4.0068
# 			* worstperimeter: +108.5082
# 			* worstarea: +3099.6640
# 			* worstconcavepoints: +0.0466
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (164/165 = 99.4% / MeanCost = 0.602):
# 			* meanconcavepoints: +0.0452
# 			* areaerror: +503.2741
# 			* worstradius: +7.3990
# 			* worsttexture: +4.8724
# 			* worstperimeter: +53.3870
# 			* worstarea: +756.7600
# 			* worstconcavity: +0.1903
# 			* worstconcavepoints: +0.0897
# - Else:
# 	- If meanarea<494.52:
# 		- If meancompactness<0.1088:
# 			- If meanarea<396.4:
# 				- If smoothnesserror<0.0059:
# 					* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.582):
# 						* meanconcavepoints: +0.0607
# 						* worstradius: +6.6718
# 						* worsttexture: +10.0328
# 						* worstperimeter: +57.9776
# 						* worstarea: +728.6120
# 						* worstsmoothness: +0.0894
# 						* worstconcavity: +0.9155
# 						* worstconcavepoints: +0.1531
# 				- Else:
# 					- If worstperimeter<81.246:
# 						* Action [Cancer: Bad -> Good] (15/17 = 88.2% / MeanCost = 0.689):
# 							* meanconcavepoints: +0.0483
# 							* radiuserror: +2.1946
# 							* areaerror: +502.8221
# 							* worsttexture: +9.7160
# 							* worstperimeter: +40.1580
# 							* worstarea: +569.6320
# 							* worstsmoothness: +0.0574
# 							* worstconcavepoints: +0.0989
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.461):
# 							* radiuserror: +1.5523
# 							* perimetererror: +19.4160
# 							* areaerror: +50.2798
# 							* worsttexture: +7.8128
# 							* worstperimeter: +33.2528
# 							* worstsmoothness: +0.0899
# 							* worstconcavity: +0.9581
# 							* worstconcavepoints: +0.1222
# 			- Else:
# 				* Action [Cancer: Bad -> Good] (3/3 = 100.0% / MeanCost = 0.326):
# 					* meantexture: +14.7616
# 					* meanconcavepoints: +0.0300
# 					* worstradius: +3.3830
# 					* worsttexture: +13.3910
# 					* worstperimeter: +22.1512
# 					* worstarea: +322.3080
# 					* worstconcavity: +0.1646
# 					* worstconcavepoints: +0.0551
# 		- Else:
# 			* Action [Cancer: Bad -> Good] (20/21 = 95.2% / MeanCost = 0.589):
# 				* meanconcavepoints: +0.0749
# 				* radiuserror: +0.4342
# 				* areaerror: +403.4945
# 				* worsttexture: +6.1948
# 				* worstperimeter: +28.0464
# 				* worstarea: +368.4800
# 				* worstcompactness: +0.6227
# 				* worstconcavepoints: +0.0954
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (7/7 = 100.0% / MeanCost = 0.341):
# 			* meanradius: +5.3107
# 			* meanconcavepoints: +0.0534
# 			* worstradius: +6.9228
# 			* worsttexture: +4.3648
# 			* worstperimeter: +54.7150
# 			* worstarea: +709.5640
# 			* worstconcavity: +0.1650
# 			* worstconcavepoints: +0.0669
#
# #### After "Replace"
# - If meanfractaldimension<0.0676:
# 	- If compactnesserror<0.0117:
# 		* Action [Cancer: Bad -> Good] (74/74 = 100.0% / MeanCost = 0.738):
# 			* meanradius: +10.2081
# 			* radiuserror: +2.3715
# 			* areaerror: +501.1211
# 			* worstradius: +16.6584
# 			* worsttexture: +4.0068
# 			* worstperimeter: +108.5082
# 			* worstarea: +3099.6640
# 			* worstconcavepoints: +0.0466
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (164/165 = 99.4% / MeanCost = 0.602):
# 			* meanconcavepoints: +0.0452
# 			* areaerror: +503.2741
# 			* worstradius: +7.3990
# 			* worsttexture: +4.8724
# 			* worstperimeter: +53.3870
# 			* worstarea: +756.7600
# 			* worstconcavity: +0.1903
# 			* worstconcavepoints: +0.0897
# - Else:
# 	- If meanarea<494.52:
# 		- If meancompactness<0.1088:
# 			- If meanarea<396.4:
# 				- If smoothnesserror<0.0059:
# 					* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.582):
# 						* meanconcavepoints: +0.0607
# 						* worstradius: +6.6718
# 						* worsttexture: +10.0328
# 						* worstperimeter: +57.9776
# 						* worstarea: +728.6120
# 						* worstsmoothness: +0.0894
# 						* worstconcavity: +0.9155
# 						* worstconcavepoints: +0.1531
# 				- Else:
# 					- (+) If worstconcavity<0.0906:
# 						* (+) Action [Cancer: Bad -> Good] (0/10 = 0.0% / MeanCost = 0.597):
# 							* meantexture: +3.1840
# 							* radiuserror: +2.2019
# 							* textureerror: +2.8222
# 							* perimetererror: +17.0159
# 							* areaerror: +500.2871
# 							* worsttexture: +4.3736
# 							* worstperimeter: +16.0632
# 							* worstconcavepoints: +0.0407
# 					- Else:
# 						* (+) Action [Cancer: Bad -> Good] (8/8 = 100.0% / MeanCost = 0.678):
# 							* meanconcavepoints: +0.0383
# 							* areaerror: +513.5301
# 							* worsttexture: +10.2650
# 							* worstperimeter: +31.2838
# 							* worstarea: +397.8560
# 							* worstsmoothness: +0.0569
# 							* worstconcavity: +0.2314
# 							* worstconcavepoints: +0.0775
# 			- Else:
# 				* Action [Cancer: Bad -> Good] (3/3 = 100.0% / MeanCost = 0.326):
# 					* meantexture: +14.7616
# 					* meanconcavepoints: +0.0300
# 					* worstradius: +3.3830
# 					* worsttexture: +13.3910
# 					* worstperimeter: +22.1512
# 					* worstarea: +322.3080
# 					* worstconcavity: +0.1646
# 					* worstconcavepoints: +0.0551
# 		- Else:
# 			* Action [Cancer: Bad -> Good] (20/21 = 95.2% / MeanCost = 0.589):
# 				* meanconcavepoints: +0.0749
# 				* radiuserror: +0.4342
# 				* areaerror: +403.4945
# 				* worsttexture: +6.1948
# 				* worstperimeter: +28.0464
# 				* worstarea: +368.4800
# 				* worstcompactness: +0.6227
# 				* worstconcavepoints: +0.0954
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (7/7 = 100.0% / MeanCost = 0.341):
# 			* meanradius: +5.3107
# 			* meanconcavepoints: +0.0534
# 			* worstradius: +6.9228
# 			* worsttexture: +4.3648
# 			* worstperimeter: +54.7150
# 			* worstarea: +709.5640
# 			* worstconcavity: +0.1650
# 			* worstconcavepoints: +0.0669
#
# ##### Score:
# - Objective: 0.7253147398841857 => 0.7502889962686227
# - Update: True
# - Best: False
# - Time: 902.7844842990016
#
# ### Iteration: 20
# #### Before:
# - If meanfractaldimension<0.0676:
# 	- If compactnesserror<0.0117:
# 		* Action [Cancer: Bad -> Good] (74/74 = 100.0% / MeanCost = 0.738):
# 			* meanradius: +10.2081
# 			* radiuserror: +2.3715
# 			* areaerror: +501.1211
# 			* worstradius: +16.6584
# 			* worsttexture: +4.0068
# 			* worstperimeter: +108.5082
# 			* worstarea: +3099.6640
# 			* worstconcavepoints: +0.0466
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (164/165 = 99.4% / MeanCost = 0.602):
# 			* meanconcavepoints: +0.0452
# 			* areaerror: +503.2741
# 			* worstradius: +7.3990
# 			* worsttexture: +4.8724
# 			* worstperimeter: +53.3870
# 			* worstarea: +756.7600
# 			* worstconcavity: +0.1903
# 			* worstconcavepoints: +0.0897
# - Else:
# 	- If meanarea<494.52:
# 		- If meancompactness<0.1088:
# 			- If meanarea<396.4:
# 				- If smoothnesserror<0.0059:
# 					* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.582):
# 						* meanconcavepoints: +0.0607
# 						* worstradius: +6.6718
# 						* worsttexture: +10.0328
# 						* worstperimeter: +57.9776
# 						* worstarea: +728.6120
# 						* worstsmoothness: +0.0894
# 						* worstconcavity: +0.9155
# 						* worstconcavepoints: +0.1531
# 				- Else:
# 					- If worstconcavity<0.0906:
# 						- If worstfractaldimension<0.0832:
# 							- If areaerror<16.406:
# 								* Action [Cancer: Bad -> Good] (0/2 = 0.0% / MeanCost = 0.0):
# 							- Else:
# 								* Action [Cancer: Bad -> Good] (0/2 = 0.0% / MeanCost = 0.316):
# 									* radiuserror: +2.1917
# 									* perimetererror: +17.3946
# 									* areaerror: +486.1641
# 									* worstradius: +2.5320
# 									* worsttexture: +3.9192
# 									* worstperimeter: +16.6922
# 									* worstarea: +223.4800
# 									* worstconcavepoints: +0.0382
# 						- Else:
# 							- If worstsmoothness<0.1382:
# 								- If worsttexture<30.812:
# 									* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.521):
# 										* meantexture: +19.3400
# 										* radiuserror: +2.5932
# 										* perimetererror: +19.8480
# 										* areaerror: +72.4157
# 										* worstradius: +4.8808
# 										* worsttexture: +19.1200
# 										* worstperimeter: +37.8212
# 										* worstsmoothness: +0.0910
# 								- Else:
# 									* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.612):
# 										* radiuserror: +2.5505
# 										* perimetererror: +19.4880
# 										* areaerror: +394.5645
# 										* worsttexture: +14.4900
# 										* worstperimeter: +49.4612
# 										* worstarea: +344.0800
# 										* worstconcavity: +0.3005
# 							- Else:
# 								- If compactnesserror<0.0117:
# 									* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.0):
# 								- Else:
# 									- If perimetererror<2.5722:
# 										* Action [Cancer: Bad -> Good] (2/2 = 100.0% / MeanCost = 0.659):
# 											* meanconcavepoints: +0.0855
# 											* radiuserror: +2.6263
# 											* areaerror: +109.5396
# 											* worsttexture: +22.5700
# 											* worstperimeter: +58.7860
# 											* worstarea: +867.4880
# 											* worstsmoothness: +0.0820
# 											* worstconcavepoints: +0.1421
# 									- Else:
# 										* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.428):
# 											* radiuserror: +2.3561
# 											* textureerror: +2.8060
# 											* perimetererror: +18.8130
# 											* areaerror: +159.9873
# 											* worstradius: +4.5064
# 											* worsttexture: +7.2506
# 											* worstperimeter: +30.5738
# 											* worstsmoothness: +0.0766
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (8/8 = 100.0% / MeanCost = 0.678):
# 							* meanconcavepoints: +0.0383
# 							* areaerror: +513.5301
# 							* worsttexture: +10.2650
# 							* worstperimeter: +31.2838
# 							* worstarea: +397.8560
# 							* worstsmoothness: +0.0569
# 							* worstconcavity: +0.2314
# 							* worstconcavepoints: +0.0775
# 			- Else:
# 				* Action [Cancer: Bad -> Good] (3/3 = 100.0% / MeanCost = 0.326):
# 					* meantexture: +14.7616
# 					* meanconcavepoints: +0.0300
# 					* worstradius: +3.3830
# 					* worsttexture: +13.3910
# 					* worstperimeter: +22.1512
# 					* worstarea: +322.3080
# 					* worstconcavity: +0.1646
# 					* worstconcavepoints: +0.0551
# 		- Else:
# 			* Action [Cancer: Bad -> Good] (20/21 = 95.2% / MeanCost = 0.589):
# 				* meanconcavepoints: +0.0749
# 				* radiuserror: +0.4342
# 				* areaerror: +403.4945
# 				* worsttexture: +6.1948
# 				* worstperimeter: +28.0464
# 				* worstarea: +368.4800
# 				* worstcompactness: +0.6227
# 				* worstconcavepoints: +0.0954
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (7/7 = 100.0% / MeanCost = 0.341):
# 			* meanradius: +5.3107
# 			* meanconcavepoints: +0.0534
# 			* worstradius: +6.9228
# 			* worsttexture: +4.3648
# 			* worstperimeter: +54.7150
# 			* worstarea: +709.5640
# 			* worstconcavity: +0.1650
# 			* worstconcavepoints: +0.0669
#
# #### After "Insert"
# - If meanfractaldimension<0.0676:
# 	- If compactnesserror<0.0117:
# 		* Action [Cancer: Bad -> Good] (74/74 = 100.0% / MeanCost = 0.738):
# 			* meanradius: +10.2081
# 			* radiuserror: +2.3715
# 			* areaerror: +501.1211
# 			* worstradius: +16.6584
# 			* worsttexture: +4.0068
# 			* worstperimeter: +108.5082
# 			* worstarea: +3099.6640
# 			* worstconcavepoints: +0.0466
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (164/165 = 99.4% / MeanCost = 0.602):
# 			* meanconcavepoints: +0.0452
# 			* areaerror: +503.2741
# 			* worstradius: +7.3990
# 			* worsttexture: +4.8724
# 			* worstperimeter: +53.3870
# 			* worstarea: +756.7600
# 			* worstconcavity: +0.1903
# 			* worstconcavepoints: +0.0897
# - Else:
# 	- If meanarea<494.52:
# 		- If meancompactness<0.1088:
# 			- If meanarea<396.4:
# 				- If smoothnesserror<0.0059:
# 					* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.582):
# 						* meanconcavepoints: +0.0607
# 						* worstradius: +6.6718
# 						* worsttexture: +10.0328
# 						* worstperimeter: +57.9776
# 						* worstarea: +728.6120
# 						* worstsmoothness: +0.0894
# 						* worstconcavity: +0.9155
# 						* worstconcavepoints: +0.1531
# 				- Else:
# 					- If worstconcavity<0.0906:
# 						- If worstfractaldimension<0.0832:
# 							- If areaerror<16.406:
# 								* Action [Cancer: Bad -> Good] (0/2 = 0.0% / MeanCost = 0.0):
# 							- Else:
# 								- (+) If fractaldimensionerror<0.0048:
# 									* (+) Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.188):
# 										* radiuserror: +2.2317
# 										* textureerror: +3.1380
# 										* perimetererror: +17.7975
# 										* areaerror: +48.9457
# 										* worstradius: +1.7798
# 										* worsttexture: +2.8738
# 										* worstperimeter: +10.7464
# 										* worstconcavepoints: +0.0298
# 								- Else:
# 									* (+) Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.359):
# 										* radiuserror: +2.4124
# 										* perimetererror: +18.6680
# 										* areaerror: +443.3322
# 										* worstradius: +3.0942
# 										* worsttexture: +6.5904
# 										* worstperimeter: +24.7238
# 										* worstarea: +304.8560
# 										* worstconcavepoints: +0.0615
# 						- Else:
# 							- If worstsmoothness<0.1382:
# 								- If worsttexture<30.812:
# 									* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.521):
# 										* meantexture: +19.3400
# 										* radiuserror: +2.5932
# 										* perimetererror: +19.8480
# 										* areaerror: +72.4157
# 										* worstradius: +4.8808
# 										* worsttexture: +19.1200
# 										* worstperimeter: +37.8212
# 										* worstsmoothness: +0.0910
# 								- Else:
# 									* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.612):
# 										* radiuserror: +2.5505
# 										* perimetererror: +19.4880
# 										* areaerror: +394.5645
# 										* worsttexture: +14.4900
# 										* worstperimeter: +49.4612
# 										* worstarea: +344.0800
# 										* worstconcavity: +0.3005
# 							- Else:
# 								- If compactnesserror<0.0117:
# 									* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.0):
# 								- Else:
# 									- If perimetererror<2.5722:
# 										* Action [Cancer: Bad -> Good] (2/2 = 100.0% / MeanCost = 0.659):
# 											* meanconcavepoints: +0.0855
# 											* radiuserror: +2.6263
# 											* areaerror: +109.5396
# 											* worsttexture: +22.5700
# 											* worstperimeter: +58.7860
# 											* worstarea: +867.4880
# 											* worstsmoothness: +0.0820
# 											* worstconcavepoints: +0.1421
# 									- Else:
# 										* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.428):
# 											* radiuserror: +2.3561
# 											* textureerror: +2.8060
# 											* perimetererror: +18.8130
# 											* areaerror: +159.9873
# 											* worstradius: +4.5064
# 											* worsttexture: +7.2506
# 											* worstperimeter: +30.5738
# 											* worstsmoothness: +0.0766
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (8/8 = 100.0% / MeanCost = 0.678):
# 							* meanconcavepoints: +0.0383
# 							* areaerror: +513.5301
# 							* worsttexture: +10.2650
# 							* worstperimeter: +31.2838
# 							* worstarea: +397.8560
# 							* worstsmoothness: +0.0569
# 							* worstconcavity: +0.2314
# 							* worstconcavepoints: +0.0775
# 			- Else:
# 				* Action [Cancer: Bad -> Good] (3/3 = 100.0% / MeanCost = 0.326):
# 					* meantexture: +14.7616
# 					* meanconcavepoints: +0.0300
# 					* worstradius: +3.3830
# 					* worsttexture: +13.3910
# 					* worstperimeter: +22.1512
# 					* worstarea: +322.3080
# 					* worstconcavity: +0.1646
# 					* worstconcavepoints: +0.0551
# 		- Else:
# 			* Action [Cancer: Bad -> Good] (20/21 = 95.2% / MeanCost = 0.589):
# 				* meanconcavepoints: +0.0749
# 				* radiuserror: +0.4342
# 				* areaerror: +403.4945
# 				* worsttexture: +6.1948
# 				* worstperimeter: +28.0464
# 				* worstarea: +368.4800
# 				* worstcompactness: +0.6227
# 				* worstconcavepoints: +0.0954
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (7/7 = 100.0% / MeanCost = 0.341):
# 			* meanradius: +5.3107
# 			* meanconcavepoints: +0.0534
# 			* worstradius: +6.9228
# 			* worsttexture: +4.3648
# 			* worstperimeter: +54.7150
# 			* worstarea: +709.5640
# 			* worstconcavity: +0.1650
# 			* worstconcavepoints: +0.0669
#
# ##### Score:
# - Objective: 0.7948699837939489 => 0.8045779948426898
# - Update: True
# - Best: False
# - Time: 913.345481352997
#
# Ckeckpoint !
# ### Iteration: 30
# #### Before:
# - If worstperimeter<91.102:
# 	- If worstsmoothness<0.0712:
# 		* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.635):
# 			* meantexture: +21.0600
# 			* radiuserror: +2.5743
# 			* perimetererror: +19.7500
# 			* areaerror: +520.5100
# 			* worstradius: +6.9572
# 			* worsttexture: +11.8918
# 			* worstperimeter: +48.3970
# 			* worstarea: +695.1600
# 	- Else:
# 		- If areaerror<28.976:
# 			* Action [Cancer: Bad -> Good] (164/164 = 100.0% / MeanCost = 0.68):
# 				* meanconcavepoints: +0.0604
# 				* radiuserror: +0.6069
# 				* areaerror: +513.9821
# 				* worstradius: +8.4330
# 				* worsttexture: +4.0068
# 				* worstperimeter: +60.2370
# 				* worstarea: +895.1360
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- If worstconcavity<0.0906:
# 				* Action [Cancer: Bad -> Good] (0/11 = 0.0% / MeanCost = 0.349):
# 					* radiuserror: +2.2193
# 					* perimetererror: +17.3707
# 					* areaerror: +491.6741
# 					* worstradius: +1.9376
# 					* worsttexture: +3.8514
# 					* worstperimeter: +12.0206
# 					* worstarea: +180.1040
# 					* worstconcavepoints: +0.0349
# 			- Else:
# 				- If compactnesserror<0.0359:
# 					* Action [Cancer: Bad -> Good] (2/3 = 66.7% / MeanCost = 0.43):
# 						* meanconcavepoints: +0.0383
# 						* radiuserror: +2.3712
# 						* perimetererror: +17.8641
# 						* areaerror: +512.0200
# 						* worstradius: +4.1332
# 						* worsttexture: +7.6760
# 						* worstperimeter: +33.3296
# 						* worstconcavepoints: +0.0746
# 				- Else:
# 					* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.293):
# 						* meantexture: +5.1264
# 						* meanconcavepoints: +0.0648
# 						* radiuserror: +2.3864
# 						* areaerror: +57.7857
# 						* worsttexture: +4.3816
# 						* worstperimeter: +16.3138
# 						* worstarea: +235.8560
# 						* worstconcavepoints: +0.0640
# - Else:
# 	* Action [Cancer: Bad -> Good] (107/109 = 98.2% / MeanCost = 0.464):
# 		* meanradius: +7.0458
# 		* areaerror: +17.4479
# 		* worstradius: +14.8292
# 		* worsttexture: +4.8724
# 		* worstperimeter: +127.7836
# 		* worstarea: +1511.6480
# 		* worstconcavity: +0.1641
# 		* worstconcavepoints: +0.0710
#
# #### After "Insert"
# - If worstperimeter<91.102:
# 	- If worstsmoothness<0.0712:
# 		* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.635):
# 			* meantexture: +21.0600
# 			* radiuserror: +2.5743
# 			* perimetererror: +19.7500
# 			* areaerror: +520.5100
# 			* worstradius: +6.9572
# 			* worsttexture: +11.8918
# 			* worstperimeter: +48.3970
# 			* worstarea: +695.1600
# 	- Else:
# 		- If areaerror<28.976:
# 			* Action [Cancer: Bad -> Good] (164/164 = 100.0% / MeanCost = 0.68):
# 				* meanconcavepoints: +0.0604
# 				* radiuserror: +0.6069
# 				* areaerror: +513.9821
# 				* worstradius: +8.4330
# 				* worsttexture: +4.0068
# 				* worstperimeter: +60.2370
# 				* worstarea: +895.1360
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- If worstconcavity<0.0906:
# 				- (+) If meanarea<396.4:
# 					* (+) Action [Cancer: Bad -> Good] (0/4 = 0.0% / MeanCost = 0.36):
# 						* meantexture: +3.1096
# 						* radiuserror: +2.1917
# 						* perimetererror: +17.3946
# 						* areaerror: +470.2582
# 						* worstradius: +2.4998
# 						* worsttexture: +3.9192
# 						* worstperimeter: +16.0364
# 						* worstconcavepoints: +0.0407
# 				- Else:
# 					* (+) Action [Cancer: Bad -> Good] (0/7 = 0.0% / MeanCost = 0.337):
# 						* radiuserror: +2.2745
# 						* perimetererror: +7.1837
# 						* areaerror: +447.8022
# 						* worstradius: +1.7142
# 						* worsttexture: +3.8514
# 						* worstperimeter: +11.1080
# 						* worstconcavity: +0.0983
# 						* worstconcavepoints: +0.0354
# 			- Else:
# 				- If compactnesserror<0.0359:
# 					* Action [Cancer: Bad -> Good] (2/3 = 66.7% / MeanCost = 0.43):
# 						* meanconcavepoints: +0.0383
# 						* radiuserror: +2.3712
# 						* perimetererror: +17.8641
# 						* areaerror: +512.0200
# 						* worstradius: +4.1332
# 						* worsttexture: +7.6760
# 						* worstperimeter: +33.3296
# 						* worstconcavepoints: +0.0746
# 				- Else:
# 					* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.293):
# 						* meantexture: +5.1264
# 						* meanconcavepoints: +0.0648
# 						* radiuserror: +2.3864
# 						* areaerror: +57.7857
# 						* worsttexture: +4.3816
# 						* worstperimeter: +16.3138
# 						* worstarea: +235.8560
# 						* worstconcavepoints: +0.0640
# - Else:
# 	* Action [Cancer: Bad -> Good] (107/109 = 98.2% / MeanCost = 0.464):
# 		* meanradius: +7.0458
# 		* areaerror: +17.4479
# 		* worstradius: +14.8292
# 		* worsttexture: +4.8724
# 		* worstperimeter: +127.7836
# 		* worstarea: +1511.6480
# 		* worstconcavity: +0.1641
# 		* worstconcavepoints: +0.0710
#
# ##### Score:
# - Objective: 0.6903815466974834 => 0.7002645989198635
# - Update: True
# - Best: False
# - Time: 2216.0847187559993
# ### Iteration: 40
# #### Before:
# - If worstperimeter<91.102:
# 	- If worstsmoothness<0.0712:
# 		* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.635):
# 			* meantexture: +21.0600
# 			* radiuserror: +2.5743
# 			* perimetererror: +19.7500
# 			* areaerror: +520.5100
# 			* worstradius: +6.9572
# 			* worsttexture: +11.8918
# 			* worstperimeter: +48.3970
# 			* worstarea: +695.1600
# 	- Else:
# 		- If textureerror<1.556:
# 			* Action [Cancer: Bad -> Good] (130/130 = 100.0% / MeanCost = 0.764):
# 				* meanradius: +8.8742
# 				* meanconcavepoints: +0.0684
# 				* areaerror: +513.9821
# 				* worstradius: +17.4282
# 				* worsttexture: +9.3492
# 				* worstperimeter: +120.4740
# 				* worstarea: +3661.9200
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- If worstconcavity<0.0906:
# 				- If meanarea<396.4:
# 					- If worstsymmetry<0.2682:
# 						* Action [Cancer: Bad -> Good] (5/7 = 71.4% / MeanCost = 0.645):
# 							* meantexture: +6.8280
# 							* radiuserror: +0.4624
# 							* areaerror: +521.4120
# 							* worstradius: +5.6308
# 							* worsttexture: +8.5560
# 							* worstperimeter: +38.6054
# 							* worstarea: +519.2080
# 							* worstconcavepoints: +0.1048
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (10/10 = 100.0% / MeanCost = 0.736):
# 							* radiuserror: +2.1947
# 							* perimetererror: +17.7318
# 							* areaerror: +507.6641
# 							* worstradius: +11.8578
# 							* worsttexture: +4.1726
# 							* worstperimeter: +80.7134
# 							* worstarea: +1376.0680
# 							* worstconcavity: +0.3255
# 				- Else:
# 					- If concavepointserror<0.0096:
# 						* Action [Cancer: Bad -> Good] (2/2 = 100.0% / MeanCost = 0.548):
# 							* meantexture: +7.1850
# 							* areaerror: +56.5798
# 							* worstradius: +7.1662
# 							* worsttexture: +18.9300
# 							* worstperimeter: +51.1560
# 							* worstarea: +753.5880
# 							* worstsmoothness: +0.0840
# 							* worstconcavepoints: +0.1024
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (0/4 = 0.0% / MeanCost = 0.4):
# 							* meantexture: +2.1724
# 							* radiuserror: +0.5374
# 							* textureerror: +2.3230
# 							* perimetererror: +3.4071
# 							* areaerror: +463.7922
# 							* worstradius: +1.7142
# 							* worsttexture: +3.7148
# 							* worstperimeter: +11.1080
# 			- Else:
# 				- If compactnesserror<0.0359:
# 					- If concavepointserror<0.0069:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.333):
# 							* meantexture: +15.8030
# 							* textureerror: +3.3140
# 							* worstradius: +3.5852
# 							* worsttexture: +12.5700
# 							* worstperimeter: +22.0512
# 							* worstarea: +288.4080
# 							* worstconcavity: +0.1609
# 							* worstconcavepoints: +0.0596
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (14/17 = 82.4% / MeanCost = 0.58):
# 							* meanconcavepoints: +0.0496
# 							* radiuserror: +0.6258
# 							* areaerror: +499.9861
# 							* worstradius: +3.7042
# 							* worsttexture: +6.9162
# 							* worstperimeter: +27.5538
# 							* worstarea: +342.7560
# 							* worstconcavepoints: +0.0690
# 				- Else:
# 					* Action [Cancer: Bad -> Good] (6/8 = 75.0% / MeanCost = 0.556):
# 						* meanconcavepoints: +0.0870
# 						* radiuserror: +2.4036
# 						* textureerror: +2.6885
# 						* areaerror: +371.3706
# 						* worstradius: +3.3356
# 						* worsttexture: +5.6960
# 						* worstperimeter: +20.4406
# 						* worstconcavepoints: +0.0841
# - Else:
# 	* Action [Cancer: Bad -> Good] (107/109 = 98.2% / MeanCost = 0.464):
# 		* meanradius: +7.0458
# 		* areaerror: +17.4479
# 		* worstradius: +14.8292
# 		* worsttexture: +4.8724
# 		* worstperimeter: +127.7836
# 		* worstarea: +1511.6480
# 		* worstconcavity: +0.1641
# 		* worstconcavepoints: +0.0710
#
# #### After "Insert"
# - If worstperimeter<91.102:
# 	- If worstsmoothness<0.0712:
# 		* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.635):
# 			* meantexture: +21.0600
# 			* radiuserror: +2.5743
# 			* perimetererror: +19.7500
# 			* areaerror: +520.5100
# 			* worstradius: +6.9572
# 			* worsttexture: +11.8918
# 			* worstperimeter: +48.3970
# 			* worstarea: +695.1600
# 	- Else:
# 		- If textureerror<1.556:
# 			* Action [Cancer: Bad -> Good] (130/130 = 100.0% / MeanCost = 0.764):
# 				* meanradius: +8.8742
# 				* meanconcavepoints: +0.0684
# 				* areaerror: +513.9821
# 				* worstradius: +17.4282
# 				* worsttexture: +9.3492
# 				* worstperimeter: +120.4740
# 				* worstarea: +3661.9200
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- If worstconcavity<0.0906:
# 				- If meanarea<396.4:
# 					- If worstsymmetry<0.2682:
# 						* Action [Cancer: Bad -> Good] (5/7 = 71.4% / MeanCost = 0.645):
# 							* meantexture: +6.8280
# 							* radiuserror: +0.4624
# 							* areaerror: +521.4120
# 							* worstradius: +5.6308
# 							* worsttexture: +8.5560
# 							* worstperimeter: +38.6054
# 							* worstarea: +519.2080
# 							* worstconcavepoints: +0.1048
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (10/10 = 100.0% / MeanCost = 0.736):
# 							* radiuserror: +2.1947
# 							* perimetererror: +17.7318
# 							* areaerror: +507.6641
# 							* worstradius: +11.8578
# 							* worsttexture: +4.1726
# 							* worstperimeter: +80.7134
# 							* worstarea: +1376.0680
# 							* worstconcavity: +0.3255
# 				- Else:
# 					- If concavepointserror<0.0096:
# 						* Action [Cancer: Bad -> Good] (2/2 = 100.0% / MeanCost = 0.548):
# 							* meantexture: +7.1850
# 							* areaerror: +56.5798
# 							* worstradius: +7.1662
# 							* worsttexture: +18.9300
# 							* worstperimeter: +51.1560
# 							* worstarea: +753.5880
# 							* worstsmoothness: +0.0840
# 							* worstconcavepoints: +0.1024
# 					- Else:
# 						- (+) If radiuserror<0.5368:
# 							* (+) Action [Cancer: Bad -> Good] (0/2 = 0.0% / MeanCost = 0.556):
# 								* radiuserror: +0.5374
# 								* textureerror: +2.5945
# 								* areaerror: +442.3763
# 								* worstradius: +4.0252
# 								* worsttexture: +6.5016
# 								* worstperimeter: +28.8870
# 								* worstsmoothness: +0.0143
# 								* worstsymmetry: -0.0336
# 						- Else:
# 							* (+) Action [Cancer: Bad -> Good] (0/2 = 0.0% / MeanCost = 0.153):
# 								* radiuserror: +2.2669
# 								* textureerror: +2.3205
# 								* perimetererror: +5.2252
# 								* areaerror: +36.7977
# 								* worstradius: +1.1520
# 								* worstperimeter: +7.0922
# 								* worstarea: +119.6800
# 								* worstconcavepoints: +0.0202
# 			- Else:
# 				- If compactnesserror<0.0359:
# 					- If concavepointserror<0.0069:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.333):
# 							* meantexture: +15.8030
# 							* textureerror: +3.3140
# 							* worstradius: +3.5852
# 							* worsttexture: +12.5700
# 							* worstperimeter: +22.0512
# 							* worstarea: +288.4080
# 							* worstconcavity: +0.1609
# 							* worstconcavepoints: +0.0596
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (14/17 = 82.4% / MeanCost = 0.58):
# 							* meanconcavepoints: +0.0496
# 							* radiuserror: +0.6258
# 							* areaerror: +499.9861
# 							* worstradius: +3.7042
# 							* worsttexture: +6.9162
# 							* worstperimeter: +27.5538
# 							* worstarea: +342.7560
# 							* worstconcavepoints: +0.0690
# 				- Else:
# 					* Action [Cancer: Bad -> Good] (6/8 = 75.0% / MeanCost = 0.556):
# 						* meanconcavepoints: +0.0870
# 						* radiuserror: +2.4036
# 						* textureerror: +2.6885
# 						* areaerror: +371.3706
# 						* worstradius: +3.3356
# 						* worsttexture: +5.6960
# 						* worstperimeter: +20.4406
# 						* worstconcavepoints: +0.0841
# - Else:
# 	* Action [Cancer: Bad -> Good] (107/109 = 98.2% / MeanCost = 0.464):
# 		* meanradius: +7.0458
# 		* areaerror: +17.4479
# 		* worstradius: +14.8292
# 		* worsttexture: +4.8724
# 		* worstperimeter: +127.7836
# 		* worstarea: +1511.6480
# 		* worstconcavity: +0.1641
# 		* worstconcavepoints: +0.0710
#
# ##### Score:
# - Objective: 0.7669078075745128 => 0.7762740965819077
# - Update: True
# - Best: False
# - Time: 2476.058361036994
#
# Ckeckpoint !
# ### Iteration: 50
# #### Before:
# - If worstperimeter<91.102:
# 	- If worstsmoothness<0.0712:
# 		* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.635):
# 			* meantexture: +21.0600
# 			* radiuserror: +2.5743
# 			* perimetererror: +19.7500
# 			* areaerror: +520.5100
# 			* worstradius: +6.9572
# 			* worsttexture: +11.8918
# 			* worstperimeter: +48.3970
# 			* worstarea: +695.1600
# 	- Else:
# 		- If textureerror<1.556:
# 			* Action [Cancer: Bad -> Good] (130/130 = 100.0% / MeanCost = 0.764):
# 				* meanradius: +8.8742
# 				* meanconcavepoints: +0.0684
# 				* areaerror: +513.9821
# 				* worstradius: +17.4282
# 				* worsttexture: +9.3492
# 				* worstperimeter: +120.4740
# 				* worstarea: +3661.9200
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- If worstconcavity<0.0906:
# 				- If meantexture<15.698:
# 					- If worstsymmetry<0.2682:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.786):
# 							* meanconcavepoints: +0.1754
# 							* radiuserror: +2.7209
# 							* areaerror: +523.1200
# 							* worstradius: +12.8838
# 							* worsttexture: +15.2340
# 							* worstperimeter: +86.8266
# 							* worstarea: +1741.7240
# 							* worstconcavepoints: +0.1723
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.61):
# 							* radiuserror: +2.5421
# 							* textureerror: +2.9600
# 							* perimetererror: +19.8250
# 							* areaerror: +520.2200
# 							* worstradius: +7.0718
# 							* worsttexture: +10.8506
# 							* worstperimeter: +49.4944
# 							* worstarea: +753.4120
# 				- Else:
# 					- If perimetererror<3.7262:
# 						* Action [Cancer: Bad -> Good] (8/18 = 44.4% / MeanCost = 0.626):
# 							* meantexture: +4.6980
# 							* radiuserror: +2.3383
# 							* areaerror: +510.7041
# 							* worstradius: +3.9870
# 							* worsttexture: +3.8304
# 							* worstperimeter: +28.5080
# 							* worstarea: +399.5560
# 							* worstconcavepoints: +0.0582
# 					- Else:
# 						- If meantexture<18.026:
# 							* Action [Cancer: Bad -> Good] (0/1 = 0.0% / MeanCost = 0.132):
# 								* meanconcavepoints: +0.0225
# 								* radiuserror: +1.9559
# 								* textureerror: +2.5920
# 								* perimetererror: +3.5274
# 								* areaerror: +32.9177
# 								* worsttexture: +2.3792
# 								* worstperimeter: +7.0922
# 								* worstconcavepoints: +0.0211
# 						- Else:
# 							* Action [Cancer: Bad -> Good] (0/2 = 0.0% / MeanCost = 0.204):
# 								* meantexture: +2.4180
# 								* radiuserror: +2.2117
# 								* perimetererror: +17.4565
# 								* areaerror: +59.6536
# 								* worsttexture: +2.8738
# 								* worstperimeter: +10.7464
# 								* worstarea: +129.8040
# 								* worstconcavepoints: +0.0298
# 			- Else:
# 				- If compactnesserror<0.0359:
# 					- If concavepointserror<0.0069:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.333):
# 							* meantexture: +15.8030
# 							* textureerror: +3.3140
# 							* worstradius: +3.5852
# 							* worsttexture: +12.5700
# 							* worstperimeter: +22.0512
# 							* worstarea: +288.4080
# 							* worstconcavity: +0.1609
# 							* worstconcavepoints: +0.0596
# 					- Else:
# 						- If worsttexture<26.834:
# 							* Action [Cancer: Bad -> Good] (4/5 = 80.0% / MeanCost = 0.521):
# 								* meanconcavepoints: +0.0456
# 								* radiuserror: +0.6258
# 								* textureerror: +3.0305
# 								* areaerror: +510.6941
# 								* worstradius: +3.1964
# 								* worsttexture: +6.9162
# 								* worstperimeter: +27.2154
# 								* worstconcavepoints: +0.0632
# 						- Else:
# 							* Action [Cancer: Bad -> Good] (12/12 = 100.0% / MeanCost = 0.593):
# 								* meantexture: +10.5134
# 								* areaerror: +100.0216
# 								* worstradius: +7.6396
# 								* worsttexture: +7.2174
# 								* worstperimeter: +55.6644
# 								* worstarea: +831.0120
# 								* worstconcavity: +0.3566
# 								* worstconcavepoints: +0.1075
# 				- Else:
# 					* Action [Cancer: Bad -> Good] (6/8 = 75.0% / MeanCost = 0.556):
# 						* meanconcavepoints: +0.0870
# 						* radiuserror: +2.4036
# 						* textureerror: +2.6885
# 						* areaerror: +371.3706
# 						* worstradius: +3.3356
# 						* worsttexture: +5.6960
# 						* worstperimeter: +20.4406
# 						* worstconcavepoints: +0.0841
# - Else:
# 	* Action [Cancer: Bad -> Good] (107/109 = 98.2% / MeanCost = 0.464):
# 		* meanradius: +7.0458
# 		* areaerror: +17.4479
# 		* worstradius: +14.8292
# 		* worsttexture: +4.8724
# 		* worstperimeter: +127.7836
# 		* worstarea: +1511.6480
# 		* worstconcavity: +0.1641
# 		* worstconcavepoints: +0.0710
#
# #### After "Delete"
# - If worstperimeter<91.102:
# 	- If worstsmoothness<0.0712:
# 		* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.635):
# 			* meantexture: +21.0600
# 			* radiuserror: +2.5743
# 			* perimetererror: +19.7500
# 			* areaerror: +520.5100
# 			* worstradius: +6.9572
# 			* worsttexture: +11.8918
# 			* worstperimeter: +48.3970
# 			* worstarea: +695.1600
# 	- Else:
# 		- If textureerror<1.556:
# 			* Action [Cancer: Bad -> Good] (130/130 = 100.0% / MeanCost = 0.764):
# 				* meanradius: +8.8742
# 				* meanconcavepoints: +0.0684
# 				* areaerror: +513.9821
# 				* worstradius: +17.4282
# 				* worsttexture: +9.3492
# 				* worstperimeter: +120.4740
# 				* worstarea: +3661.9200
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- If worstconcavity<0.0906:
# 				- If meantexture<15.698:
# 					- If worstsymmetry<0.2682:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.786):
# 							* meanconcavepoints: +0.1754
# 							* radiuserror: +2.7209
# 							* areaerror: +523.1200
# 							* worstradius: +12.8838
# 							* worsttexture: +15.2340
# 							* worstperimeter: +86.8266
# 							* worstarea: +1741.7240
# 							* worstconcavepoints: +0.1723
# 					- Else:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.61):
# 							* radiuserror: +2.5421
# 							* textureerror: +2.9600
# 							* perimetererror: +19.8250
# 							* areaerror: +520.2200
# 							* worstradius: +7.0718
# 							* worsttexture: +10.8506
# 							* worstperimeter: +49.4944
# 							* worstarea: +753.4120
# 				- Else:
# 					- (+) If meantexture<18.026:
# 						* (+) Action [Cancer: Bad -> Good] (0/5 = 0.0% / MeanCost = 0.468):
# 							* meanconcavepoints: +0.0322
# 							* radiuserror: +0.5354
# 							* textureerror: +2.6150
# 							* areaerror: +452.7743
# 							* worstradius: +1.6954
# 							* worsttexture: +3.7148
# 							* worstperimeter: +14.5106
# 							* worstconcavepoints: +0.0466
# 					- Else:
# 						* (+) Action [Cancer: Bad -> Good] (3/16 = 18.8% / MeanCost = 0.612):
# 							* meantexture: +5.5836
# 							* radiuserror: +2.2280
# 							* perimetererror: +17.1249
# 							* areaerror: +499.9961
# 							* worstradius: +3.4248
# 							* worsttexture: +3.9016
# 							* worstperimeter: +24.4922
# 							* worstarea: +318.1800
# 			- Else:
# 				- If compactnesserror<0.0359:
# 					- If concavepointserror<0.0069:
# 						* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.333):
# 							* meantexture: +15.8030
# 							* textureerror: +3.3140
# 							* worstradius: +3.5852
# 							* worsttexture: +12.5700
# 							* worstperimeter: +22.0512
# 							* worstarea: +288.4080
# 							* worstconcavity: +0.1609
# 							* worstconcavepoints: +0.0596
# 					- Else:
# 						- If worsttexture<26.834:
# 							* Action [Cancer: Bad -> Good] (4/5 = 80.0% / MeanCost = 0.521):
# 								* meanconcavepoints: +0.0456
# 								* radiuserror: +0.6258
# 								* textureerror: +3.0305
# 								* areaerror: +510.6941
# 								* worstradius: +3.1964
# 								* worsttexture: +6.9162
# 								* worstperimeter: +27.2154
# 								* worstconcavepoints: +0.0632
# 						- Else:
# 							* Action [Cancer: Bad -> Good] (12/12 = 100.0% / MeanCost = 0.593):
# 								* meantexture: +10.5134
# 								* areaerror: +100.0216
# 								* worstradius: +7.6396
# 								* worsttexture: +7.2174
# 								* worstperimeter: +55.6644
# 								* worstarea: +831.0120
# 								* worstconcavity: +0.3566
# 								* worstconcavepoints: +0.1075
# 				- Else:
# 					* Action [Cancer: Bad -> Good] (6/8 = 75.0% / MeanCost = 0.556):
# 						* meanconcavepoints: +0.0870
# 						* radiuserror: +2.4036
# 						* textureerror: +2.6885
# 						* areaerror: +371.3706
# 						* worstradius: +3.3356
# 						* worsttexture: +5.6960
# 						* worstperimeter: +20.4406
# 						* worstconcavepoints: +0.0841
# - Else:
# 	* Action [Cancer: Bad -> Good] (107/109 = 98.2% / MeanCost = 0.464):
# 		* meanradius: +7.0458
# 		* areaerror: +17.4479
# 		* worstradius: +14.8292
# 		* worsttexture: +4.8724
# 		* worstperimeter: +127.7836
# 		* worstarea: +1511.6480
# 		* worstconcavity: +0.1641
# 		* worstconcavepoints: +0.0710
#
# ##### Score:
# - Objective: 0.7990097655889412 => 0.8073974057196567
# - Update: True
# - Best: False
# - Time: 2509.069499951991
#
# ### Iteration: 60
# #### Before:
# - If worstperimeter<91.102:
# 	- If worstconcavepoints<0.1209:
# 		* Action [Cancer: Bad -> Good] (174/174 = 100.0% / MeanCost = 0.78):
# 			* meanradius: +8.4516
# 			* meantexture: +5.9140
# 			* radiuserror: +2.0965
# 			* areaerror: +503.2741
# 			* worstradius: +14.6172
# 			* worstperimeter: +92.3634
# 			* worstarea: +3661.9200
# 			* worstconcavepoints: +0.1339
# 	- Else:
# 		- If meantexture<18.026:
# 			* Action [Cancer: Bad -> Good] (3/3 = 100.0% / MeanCost = 0.292):
# 				* meanconcavepoints: +0.0403
# 				* worstradius: +2.1176
# 				* worsttexture: +4.1782
# 				* worstperimeter: +17.0364
# 				* worstarea: +186.0040
# 				* worstsmoothness: +0.0290
# 				* worstconcavepoints: +0.1185
# 				* worstfractaldimension: +0.0910
# 		- Else:
# 			- If worsttexture<26.834:
# 				* Action [Cancer: Bad -> Good] (1/1 = 100.0% / MeanCost = 0.225):
# 					* meanconcavepoints: +0.0369
# 					* textureerror: +3.1450
# 					* worsttexture: +3.9828
# 					* worstperimeter: +14.4754
# 					* worstarea: +145.3560
# 					* worstsmoothness: +0.0446
# 					* worstconcavity: +0.1822
# 					* worstconcavepoints: +0.0679
# 			- Else:
# 				* Action [Cancer: Bad -> Good] (2/2 = 100.0% / MeanCost = 0.23):
# 					* meanconcavepoints: +0.0295
# 					* worstradius: +1.6964
# 					* worsttexture: +12.1432
# 					* worstperimeter: +13.0896
# 					* worstarea: +104.3800
# 					* worstsmoothness: +0.0477
# 					* worstconcavity: +0.0859
# 					* worstconcavepoints: +0.0586
# - Else:
# 	- If worstconcavepoints<0.0588:
# 		* Action [Cancer: Bad -> Good] (13/13 = 100.0% / MeanCost = 0.491):
# 			* meanradius: +13.1471
# 			* areaerror: +28.1559
# 			* worstradius: +19.9534
# 			* worsttexture: +6.4326
# 			* worstperimeter: +111.3804
# 			* worstarea: +3454.3480
# 			* worstconcavity: +0.1891
# 			* worstconcavepoints: +0.0710
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (96/96 = 100.0% / MeanCost = 0.438):
# 			* meanradius: +6.6232
# 			* meanconcavepoints: +0.0350
# 			* worstradius: +11.4560
# 			* worsttexture: +4.8724
# 			* worstperimeter: +83.6098
# 			* worstarea: +1348.8960
# 			* worstconcavity: +0.1778
# 			* worstconcavepoints: +0.0808
#
# #### After "Replace"
# - If worstperimeter<91.102:
# 	- (+) If worstfractaldimension<0.0832:
# 		* (+) Action [Cancer: Bad -> Good] (126/126 = 100.0% / MeanCost = 0.764):
# 			* meanconcavepoints: +0.0563
# 			* radiuserror: +0.4956
# 			* areaerror: +501.8711
# 			* worstradius: +22.0162
# 			* worstperimeter: +105.5924
# 			* worstarea: +3686.2960
# 			* worstconcavity: +0.3005
# 			* worstconcavepoints: +0.1222
# 	- Else:
# 		- (+) If meantexture<18.026:
# 			* (+) Action [Cancer: Bad -> Good] (26/27 = 96.3% / MeanCost = 0.69):
# 				* meanconcavepoints: +0.0523
# 				* radiuserror: +0.4965
# 				* areaerror: +513.5301
# 				* worstradius: +6.1842
# 				* worsttexture: +10.2016
# 				* worstperimeter: +44.1738
# 				* worstarea: +651.0080
# 				* worstconcavepoints: +0.1164
# 		- Else:
# 			- (+) If worsttexture<26.834:
# 				* (+) Action [Cancer: Bad -> Good] (11/11 = 100.0% / MeanCost = 0.575):
# 					* meantexture: +6.4350
# 					* meanconcavepoints: +0.0524
# 					* radiuserror: +0.6513
# 					* areaerror: +412.6424
# 					* worsttexture: +9.3040
# 					* worstperimeter: +29.9796
# 					* worstarea: +376.3560
# 					* worstconcavepoints: +0.1100
# 			- Else:
# 				* (+) Action [Cancer: Bad -> Good] (16/16 = 100.0% / MeanCost = 0.676):
# 					* meantexture: +13.8532
# 					* areaerror: +524.6900
# 					* worstradius: +9.3716
# 					* worsttexture: +8.2930
# 					* worstperimeter: +68.2044
# 					* worstarea: +938.1120
# 					* worstconcavity: +0.4006
# 					* worstconcavepoints: +0.1222
# - Else:
# 	- If worstconcavepoints<0.0588:
# 		* Action [Cancer: Bad -> Good] (13/13 = 100.0% / MeanCost = 0.491):
# 			* meanradius: +13.1471
# 			* areaerror: +28.1559
# 			* worstradius: +19.9534
# 			* worsttexture: +6.4326
# 			* worstperimeter: +111.3804
# 			* worstarea: +3454.3480
# 			* worstconcavity: +0.1891
# 			* worstconcavepoints: +0.0710
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (96/96 = 100.0% / MeanCost = 0.438):
# 			* meanradius: +6.6232
# 			* meanconcavepoints: +0.0350
# 			* worstradius: +11.4560
# 			* worsttexture: +4.8724
# 			* worstperimeter: +83.6098
# 			* worstarea: +1348.8960
# 			* worstconcavity: +0.1778
# 			* worstconcavepoints: +0.0808
#
# ##### Score:
# - Objective: 0.7026830883163084 => 0.687917232455413
# - Update: True
# - Best: False
# - Time: 3101.747308391001
#
# Ckeckpoint !
# KeyboardInterrupt

# %%
x_cet = cet.predict(X_vl) + X_vl
y_cet = mdl.predict(x_cet)

print('Positive accuracy of CET = {}'.format(np.mean(y_cet != mdl.predict(X_vl))))
print('Positive INlier CET = {}'.format(np.mean(isolation.predict(x_cet) == 1)))
# Out:
# Positive accuracy of CET = 0.9558823529411765
# Positive INlier CET = 0.5882352941176471

# %%
print('Sparsity', np.mean(np.sum(x_cet-X_vl!=0, axis=1)))
# Out:
# Sparsity 8.0

# %%
cet.print_tree()
# Out:
# - If worstperimeter<105.38:
# 	- If compactnesserror<0.0117:
# 		* Action [Cancer: Bad -> Good] (78/78 = 100.0% / MeanCost = 0.727):
# 			* meanradius: +9.2968
# 			* radiuserror: +0.4956
# 			* areaerror: +511.8291
# 			* worstradius: +19.6770
# 			* worsttexture: +4.0068
# 			* worstperimeter: +120.4740
# 			* worstarea: +3417.7920
# 			* worstconcavity: +0.2003
# 	- Else:
# 		* Action [Cancer: Bad -> Good] (175/182 = 96.2% / MeanCost = 0.616):
# 			* meanconcavepoints: +0.0483
# 			* radiuserror: +0.4965
# 			* areaerror: +471.1502
# 			* worstradius: +5.9984
# 			* worsttexture: +4.8724
# 			* worstperimeter: +44.1096
# 			* worstarea: +612.6080
# 			* worstconcavepoints: +0.0815
# - Else:
# 	* Action [Cancer: Bad -> Good] (29/29 = 100.0% / MeanCost = 0.242):
# 		* meanradius: +3.8829
# 		* meantexture: +1.9784
# 		* worstradius: +6.1228
# 		* worsttexture: +3.8302
# 		* worstperimeter: +40.9892
# 		* worstarea: +615.4640
# 		* worstconcavity: +0.0955
# 		* worstconcavepoints: +0.0469
