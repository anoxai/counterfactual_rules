# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from utils import MyTabNetClassifier
from acv_explainers.utils import *
from ares import AReS
from cet import CounterfactualExplanationTree
from ce import ActionExtractor
from utils import DatasetHelper, submodular_picking, DATASETS_NAME
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

seed = 2022
np.random.seed(0)

# %%
# Load Compas data

seed = 2022
np.random.seed(0)
dataset = 'c'
dataset_name = DATASETS_NAME[dataset]
model= 'X'

LAMBDA = 0.01
GAMMA = 1.0

D = DatasetHelper(dataset=dataset, feature_prefix_index=False)
X_tr, X_ts, y_tr, y_ts = D.train_test_split()

# %%
# Train IsolationForest for OutlierScore

from sklearn.ensemble import IsolationForest

isolation = IsolationForest()
isolation.fit(X_tr)
# Out:
# IsolationForest()

# %%
y_tr = 1 - y_tr
y_ts = 1 - y_ts

# %%
# Train the model to explain

mdl = LGBMClassifier(n_estimators=50, num_leaves=8)
mdl.fit(X_tr, y_tr)
# Out:
# LGBMClassifier(n_estimators=50, num_leaves=8)

# %%
D.feature_names
# Out:
# ['age',
#  'juv_fel_count',
#  'juv_misd_count',
#  'juv_other_count',
#  'priors_count',
#  'race:African-American',
#  'race:Asian',
#  'race:Caucasian',
#  'race:Hispanic',
#  'race:Native American',
#  'race:Other',
#  'c_charge_degree:F',
#  'c_charge_degree:M',
#  'gender']

# %%
D.target_name
# Out:
# 'RecidivateWithinTwoYears'

# %%
D.feature_constraints
# Out:
# ['INC',
#  '',
#  '',
#  '',
#  '',
#  'FIX',
#  'FIX',
#  'FIX',
#  'FIX',
#  'FIX',
#  'FIX',
#  '',
#  '',
#  'FIX']

# %%
D.feature_categories
# Out:
# [[5, 6, 7, 8, 9, 10], [11, 12]]

# %%
D.feature_types
# Out:
# ['I', 'I', 'I', 'I', 'I', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B']

# %%
X = X_tr[mdl.predict(X_tr)==1]
X_vl = X_ts[mdl.predict(X_ts)==1]

# %% [markdown]
# ## Actionable Recourse Summary

# %%
print('## Actionable Recourse Summary')
ares = AReS(mdl, X_tr, max_rule=4, max_rule_length=4, discretization_bins=10, minimum_support=0.05, print_objective=False,
            feature_names=D.feature_names, feature_types=D.feature_types, feature_categories=D.feature_categories, 
            feature_constraints=D.feature_constraints, target_name=D.target_name, target_labels=D.target_labels)
ares = ares.fit(X, max_change_num=4, cost_type='MPS', lambda_acc=1.0, lambda_cov=1.0, lambda_cst=1.0)
print('* Parameters:')
print('\t* lambda_acc: {}'.format(ares.lambda_acc)); print('\t* lambda_cov: {}'.format(ares.lambda_cov)); print('\t* lambda_cst: {}'.format(ares.lambda_cst));
print('\t* minimum support: {}'.format(ares.rule_miner_.minsup_)); print('\t* discretization bins: {}'.format(ares.rule_miner_.fd_.bins)); print('\t* pre-processing time[s]: {}'.format(ares.preprocess_time_)); 
print('\t* max rule: {}'.format(ares.max_rule_)); print('\t* max rule length: {}'.format(ares.max_rule_length_)); print('\t* Time[s]:', ares.time_); 
print('\t* uncover test: {}'.format(ares.uncover(X_vl))); print('\t* conflict: {}'.format(ares.conflict(X_vl))); print();
print('### Learned AReS')
print(ares.to_markdown())
# Out:
# ## Actionable Recourse Summary
# * Parameters:
# 	* lambda_acc: 1.0
# 	* lambda_cov: 1.0
# 	* lambda_cst: 1.0
# 	* minimum support: 0.05
# 	* discretization bins: 10
# 	* pre-processing time[s]: 0.6566287280002143
# 	* max rule: 4
# 	* max rule length: 4
# 	* Time[s]: 234.41160926500015
# 	* uncover test: 0.08406113537117904
# 	* conflict: 0.0
#
# ### Learned AReS
# | | Rule | Action |
# | :---: | --- | --- |
# | Recourse <br> rule 1 <br> (probability: 49.4%) | If 'juv_fel_count<1' <br> AND 'priors_count<1' | juv_fel_count<1 <br> AND priors_count>=10 |
# | Recourse <br> rule 2 <br> (probability: 24.7%) | If 'juv_fel_count<1' <br> AND '1<=priors_count<2' | juv_fel_count<1 <br> AND priors_count>=10 |
# | Recourse <br> rule 3 <br> (probability: 11.4%) | If 'juv_fel_count<1' <br> AND '2<=priors_count<3' | juv_fel_count<1 <br> AND priors_count>=10 |
# | Recourse <br> rule 4 <br> (probability: 6.6%) | If 'juv_misd_count<1' <br> AND 'juv_other_count<1' <br> AND '4<=priors_count<6' | juv_misd_count<1 <br> AND juv_other_count<1 <br> AND priors_count>=10 |
# | Default <br> rule | Else | priors_count>=10 <br> AND race:African-American <br> AND c_charge_degree:F |

# %%
x_ares = ares.predict(X_vl) + X_vl
y_ares = mdl.predict(x_ares)

print('Negative accuracy of AReS = {}'.format(np.mean(y_ares != mdl.predict(X_vl))))
print('Negative Inlier AReS = {}'.format(np.mean(isolation.predict(x_ares) == 1)))
# Out:
# Negative accuracy of AReS = 1.0
# Negative Inlier AReS = 0.618995633187773

# %%
print('Sparsity', np.mean(np.sum(x_ares-X_vl!=0, axis=1)))
# Out:
# Sparsity 1.0

# %% [markdown]
# # Counterfactual TREE

# %%
print('## Counterfactual Explanation Tree')
cet = CounterfactualExplanationTree(mdl, X_tr, y_tr, max_iteration=500, lime_approximation=(model!='L'),
                                    feature_names=D.feature_names, feature_types=D.feature_types, feature_categories=D.feature_categories,
                                    feature_constraints=D.feature_constraints, target_name=D.target_name, target_labels=D.target_labels)

cet = cet.fit(X, max_change_num=8, cost_type='MPS', C=LAMBDA, gamma=GAMMA, max_leaf_size=-1, time_limit=180, verbose=True)
print('* Parameters:'); print('\t* lambda: {}'.format(cet.lambda_)); print('\t* gamma: {}'.format(cet.gamma_)); print('\t* max_iteration: {}'.format(cet.max_iteration_));
print('\t* leaf size bound:', cet.leaf_size_bound_); print('\t* leaf size:', cet.n_leaves_); print('\t* LIME approximation:', cet.lime_approximation_); print('\t* Time[s]:', cet.time_); print();
print('### Learned CET')
cet.print_tree()
# Out:
# ## Counterfactual Explanation Tree
# ## Stochastic Local Searching ...
# ### Iteration: 10
# #### Before:
# - If priors_count<2:
# 	- If age<29:
# 		- If race:Caucasian:
# 			- If priors_count<1:
# 				- If c_charge_degree:M:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/75 = 0.0% / MeanCost = 0.0705):
# 						* juv_fel_count: +4
# 						* juv_misd_count: +13
# 						* juv_other_count: +6
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/103 = 0.0% / MeanCost = 0.0704):
# 						* juv_misd_count: +10
# 						* juv_other_count: +7
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/60 = 75.0% / MeanCost = 0.29):
# 					* juv_other_count: +5
# 					* priors_count: +3
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (53/443 = 12.0% / MeanCost = 0.0697):
# 				* juv_fel_count: +6
# 				* juv_misd_count: +12
# 				* juv_other_count: +4
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1134/1351 = 83.9% / MeanCost = 0.555):
# 			* juv_other_count: +8
# 			* priors_count: +7
# - Else:
# 	- If race:Asian:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.201):
# 			* juv_other_count: +6
# 			* priors_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (310/702 = 44.2% / MeanCost = 0.0793):
# 			* juv_other_count: +7
# 			* priors_count: +1
#
# #### After "Replace"
# - If priors_count<2:
# 	- If age<29:
# 		- If race:Caucasian:
# 			- (+) If c_charge_degree:F:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/144 = 0.0% / MeanCost = 0.0701):
# 					* juv_fel_count: +1
# 					* juv_misd_count: +10
# 					* juv_other_count: +6
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/94 = 0.0% / MeanCost = 0.0699):
# 					* juv_fel_count: +8
# 					* juv_misd_count: +13
# 					* juv_other_count: +5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (53/443 = 12.0% / MeanCost = 0.0697):
# 				* juv_fel_count: +6
# 				* juv_misd_count: +12
# 				* juv_other_count: +4
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1134/1351 = 83.9% / MeanCost = 0.555):
# 			* juv_other_count: +8
# 			* priors_count: +7
# - Else:
# 	- If race:Asian:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.201):
# 			* juv_other_count: +6
# 			* priors_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (310/702 = 44.2% / MeanCost = 0.0793):
# 			* juv_other_count: +7
# 			* priors_count: +1
#
# ##### Score:
# - Objective: 0.8220126743635257 => 0.8235936980200751
# - Update: True
# - Best: False
# - Time: 30.168810060000396
#
# ### Iteration: 20
# #### Before:
# - If priors_count<2:
# 	- If age<24:
# 		- If race:Caucasian:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/31 = 0.0% / MeanCost = 0.0632):
# 						* juv_fel_count: +1
# 						* juv_other_count: +6
# 				- Else:
# 					- If priors_count<1:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0621):
# 							* juv_other_count: +7
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0701):
# 							* juv_fel_count: +8
# 							* juv_misd_count: +3
# 							* juv_other_count: +4
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0639):
# 					* juv_fel_count: +2
# 					* juv_other_count: +6
# 		- Else:
# 			- If race:Hispanic:
# 				- If priors_count<1:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/18 = 0.0% / MeanCost = 0.0714):
# 						* juv_fel_count: +8
# 						* juv_misd_count: +13
# 						* juv_other_count: +9
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0542):
# 						* juv_other_count: +6
# 			- Else:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/14 = 0.0% / MeanCost = 0.0711):
# 						* juv_other_count: +8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (61/88 = 69.3% / MeanCost = 0.205):
# 						* juv_misd_count: +4
# 						* juv_other_count: +4
# 						* priors_count: +1
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1844/1844 = 100.0% / MeanCost = 0.627):
# 			* juv_misd_count: +1
# 			* juv_other_count: +5
# 			* priors_count: +11
# - Else:
# 	- If race:Asian:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.201):
# 			* juv_other_count: +6
# 			* priors_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (310/702 = 44.2% / MeanCost = 0.0793):
# 			* juv_other_count: +7
# 			* priors_count: +1
#
# #### After "Insert"
# - If priors_count<2:
# 	- If age<24:
# 		- If race:Caucasian:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/31 = 0.0% / MeanCost = 0.0632):
# 						* juv_fel_count: +1
# 						* juv_other_count: +6
# 				- Else:
# 					- If priors_count<1:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0621):
# 							* juv_other_count: +7
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0701):
# 							* juv_fel_count: +8
# 							* juv_misd_count: +3
# 							* juv_other_count: +4
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0639):
# 					* juv_fel_count: +2
# 					* juv_other_count: +6
# 		- Else:
# 			- If race:Hispanic:
# 				- If priors_count<1:
# 					- (+) If c_charge_degree:F:
# 						* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/8 = 0.0% / MeanCost = 0.0711):
# 							* juv_misd_count: +13
# 							* juv_other_count: +8
# 					- Else:
# 						* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/10 = 0.0% / MeanCost = 0.0711):
# 							* juv_other_count: +8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0542):
# 						* juv_other_count: +6
# 			- Else:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/14 = 0.0% / MeanCost = 0.0711):
# 						* juv_other_count: +8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (61/88 = 69.3% / MeanCost = 0.205):
# 						* juv_misd_count: +4
# 						* juv_other_count: +4
# 						* priors_count: +1
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1844/1844 = 100.0% / MeanCost = 0.627):
# 			* juv_misd_count: +1
# 			* juv_other_count: +5
# 			* priors_count: +11
# - Else:
# 	- If race:Asian:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.201):
# 			* juv_other_count: +6
# 			* priors_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (310/702 = 44.2% / MeanCost = 0.0793):
# 			* juv_other_count: +7
# 			* priors_count: +1
#
# ##### Score:
# - Objective: 0.7518098194539378 => 0.7618083974991684
# - Update: True
# - Best: False
# - Time: 44.515239469001244
#
# Ckeckpoint !
# ### Iteration: 30
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<35:
# 			- If c_charge_degree:F:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/61 = 0.0% / MeanCost = 0.0687):
# 					* juv_other_count: +8
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/58 = 0.0% / MeanCost = 0.0705):
# 					* juv_fel_count: +4
# 					* juv_other_count: +8
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/155 = 0.0% / MeanCost = 0.0714):
# 				* juv_misd_count: +7
# 				* juv_other_count: +9
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# #### After "Insert"
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<35:
# 			- If c_charge_degree:F:
# 				- (+) If gender:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/47 = 0.0% / MeanCost = 0.0679):
# 						* juv_other_count: +8
# 				- Else:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/14 = 0.0% / MeanCost = 0.0714):
# 						* juv_misd_count: +8
# 						* juv_other_count: +9
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/58 = 0.0% / MeanCost = 0.0705):
# 					* juv_fel_count: +4
# 					* juv_other_count: +8
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/155 = 0.0% / MeanCost = 0.0714):
# 				* juv_misd_count: +7
# 				* juv_other_count: +9
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# ##### Score:
# - Objective: 0.6444662568137309 => 0.6544673627785516
# - Update: True
# - Best: False
# - Time: 60.289550038000016
#
# ### Iteration: 40
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If priors_count<2:
# 					- If age<24:
# 						- If gender:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0628):
# 								* juv_fel_count: +7
# 								* juv_other_count: +3
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 					- Else:
# 						- If age<35:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/45 = 0.0% / MeanCost = 0.0689):
# 								* juv_other_count: +8
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0714):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +12
# 									* juv_other_count: +9
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/28 = 0.0% / MeanCost = 0.409):
# 									* juv_misd_count: +13
# 									* juv_other_count: +9
# 									* priors_count: +4
# 				- Else:
# 					- If age<24:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 							* juv_other_count: +1
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/28 = 0.0% / MeanCost = 0.0711):
# 							* juv_misd_count: +13
# 							* juv_other_count: +7
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/107 = 5.6% / MeanCost = 0.172):
# 						* juv_fel_count: +1
# 						* juv_misd_count: +1
# 						* juv_other_count: +8
# 						* priors_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (15/30 = 50.0% / MeanCost = 0.5):
# 						* juv_misd_count: +9
# 						* juv_other_count: +9
# 						* priors_count: +5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# #### After "Replace"
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If priors_count<2:
# 					- If age<24:
# 						- If gender:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0628):
# 								* juv_fel_count: +7
# 								* juv_other_count: +3
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 					- Else:
# 						- (+) If age<29:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0672):
# 								* juv_fel_count: +1
# 								* juv_other_count: +8
# 						- Else:
# 							- (+) If age<45:
# 								* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/45 = 0.0% / MeanCost = 0.0714):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 							- Else:
# 								* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/28 = 0.0% / MeanCost = 0.409):
# 									* juv_misd_count: +13
# 									* juv_other_count: +9
# 									* priors_count: +4
# 				- Else:
# 					- If age<24:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 							* juv_other_count: +1
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/28 = 0.0% / MeanCost = 0.0711):
# 							* juv_misd_count: +13
# 							* juv_other_count: +7
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/107 = 5.6% / MeanCost = 0.172):
# 						* juv_fel_count: +1
# 						* juv_misd_count: +1
# 						* juv_other_count: +8
# 						* priors_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (15/30 = 50.0% / MeanCost = 0.5):
# 						* juv_misd_count: +9
# 						* juv_other_count: +9
# 						* priors_count: +5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# ##### Score:
# - Objective: 0.7185131919305721 => 0.7185165888243065
# - Update: True
# - Best: False
# - Time: 64.61591099600264
#
# Ckeckpoint !
# ### Iteration: 50
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If priors_count<2:
# 					- If gender:
# 						- If age<35:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/43 = 0.0% / MeanCost = 0.0676):
# 								* juv_other_count: +8
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/44 = 4.5% / MeanCost = 0.467):
# 								* juv_misd_count: +9
# 								* juv_other_count: +9
# 								* priors_count: +5
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 						- Else:
# 							- If age<45:
# 								- If age<29:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 										* juv_misd_count: +13
# 										* juv_other_count: +8
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/11 = 0.0% / MeanCost = 0.0714):
# 										* juv_other_count: +9
# 							- Else:
# 								- If priors_count<1:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.552):
# 										* juv_fel_count: +8
# 										* juv_other_count: +9
# 										* priors_count: +5
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/2 = 0.0% / MeanCost = 0.0711):
# 										* juv_other_count: +8
# 				- Else:
# 					- If age<24:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 							* juv_other_count: +1
# 					- Else:
# 						- If age<35:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.0707):
# 								* juv_other_count: +5
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/23 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/107 = 5.6% / MeanCost = 0.172):
# 						* juv_fel_count: +1
# 						* juv_misd_count: +1
# 						* juv_other_count: +8
# 						* priors_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (15/30 = 50.0% / MeanCost = 0.5):
# 						* juv_misd_count: +9
# 						* juv_other_count: +9
# 						* priors_count: +5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# #### After "Delete"
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If priors_count<2:
# 					- If gender:
# 						- If age<35:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/43 = 0.0% / MeanCost = 0.0676):
# 								* juv_other_count: +8
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/44 = 4.5% / MeanCost = 0.467):
# 								* juv_misd_count: +9
# 								* juv_other_count: +9
# 								* priors_count: +5
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 						- Else:
# 							- If age<45:
# 								- If age<29:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 										* juv_misd_count: +13
# 										* juv_other_count: +8
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/11 = 0.0% / MeanCost = 0.0714):
# 										* juv_other_count: +9
# 							- Else:
# 								- If priors_count<1:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.552):
# 										* juv_fel_count: +8
# 										* juv_other_count: +9
# 										* priors_count: +5
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/2 = 0.0% / MeanCost = 0.0711):
# 										* juv_other_count: +8
# 				- Else:
# 					- If age<24:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 							* juv_other_count: +1
# 					- Else:
# 						- If age<35:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.0707):
# 								* juv_other_count: +5
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/23 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/137 = 0.0% / MeanCost = 0.071):
# 					* juv_fel_count: +7
# 					* juv_misd_count: +2
# 					* juv_other_count: +8
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# ##### Score:
# - Objective: 0.7508713793595957 => 0.7399032733957301
# - Update: True
# - Best: False
# - Time: 66.92985084500106
#
# ### Iteration: 60
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If priors_count<2:
# 					- If gender:
# 						- If age<35:
# 							- If priors_count<1:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0695):
# 									* juv_fel_count: +3
# 									* juv_other_count: +8
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/19 = 0.0% / MeanCost = 0.0658):
# 									* juv_other_count: +7
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/19 = 10.5% / MeanCost = 0.487):
# 									* juv_misd_count: +9
# 									* juv_other_count: +9
# 									* priors_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/25 = 0.0% / MeanCost = 0.411):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 									* priors_count: +4
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 						- Else:
# 							- If age<45:
# 								- If priors_count<1:
# 									- If age<35:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.0714):
# 											* juv_misd_count: +7
# 											* juv_other_count: +9
# 									- Else:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/4 = 0.0% / MeanCost = 0.443):
# 											* juv_fel_count: +8
# 											* juv_other_count: +9
# 											* priors_count: +3
# 								- Else:
# 									- If age<29:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0701):
# 											* juv_other_count: +4
# 									- Else:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/4 = 0.0% / MeanCost = 0.0711):
# 											* juv_other_count: +8
# 							- Else:
# 								- If priors_count<1:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.552):
# 										* juv_fel_count: +8
# 										* juv_other_count: +9
# 										* priors_count: +5
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/2 = 0.0% / MeanCost = 0.0711):
# 										* juv_other_count: +8
# 				- Else:
# 					- If age<24:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 							* juv_other_count: +1
# 					- Else:
# 						- If age<35:
# 							- If gender:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/4 = 0.0% / MeanCost = 0.0707):
# 									* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0309):
# 									* juv_fel_count: +3
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/23 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/107 = 5.6% / MeanCost = 0.172):
# 						* juv_fel_count: +1
# 						* juv_misd_count: +1
# 						* juv_other_count: +8
# 						* priors_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (15/30 = 50.0% / MeanCost = 0.5):
# 						* juv_misd_count: +9
# 						* juv_other_count: +9
# 						* priors_count: +5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# #### After "Insert"
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If race:Hispanic:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If priors_count<2:
# 					- If gender:
# 						- If age<35:
# 							- If priors_count<1:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0695):
# 									* juv_fel_count: +3
# 									* juv_other_count: +8
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/19 = 0.0% / MeanCost = 0.0658):
# 									* juv_other_count: +7
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/19 = 10.5% / MeanCost = 0.487):
# 									* juv_misd_count: +9
# 									* juv_other_count: +9
# 									* priors_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/25 = 0.0% / MeanCost = 0.411):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 									* priors_count: +4
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 						- Else:
# 							- If age<45:
# 								- If priors_count<1:
# 									- If age<35:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.0714):
# 											* juv_misd_count: +7
# 											* juv_other_count: +9
# 									- Else:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/4 = 0.0% / MeanCost = 0.443):
# 											* juv_fel_count: +8
# 											* juv_other_count: +9
# 											* priors_count: +3
# 								- Else:
# 									- If age<29:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0701):
# 											* juv_other_count: +4
# 									- Else:
# 										- (+) If age<35:
# 											* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0711):
# 												* juv_other_count: +7
# 										- Else:
# 											* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0701):
# 												* juv_fel_count: +7
# 												* juv_misd_count: +12
# 												* juv_other_count: +4
# 							- Else:
# 								- If priors_count<1:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.552):
# 										* juv_fel_count: +8
# 										* juv_other_count: +9
# 										* priors_count: +5
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/2 = 0.0% / MeanCost = 0.0711):
# 										* juv_other_count: +8
# 				- Else:
# 					- If age<24:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 							* juv_other_count: +1
# 					- Else:
# 						- If age<35:
# 							- If gender:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/4 = 0.0% / MeanCost = 0.0707):
# 									* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0309):
# 									* juv_fel_count: +3
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/23 = 0.0% / MeanCost = 0.0711):
# 								* juv_misd_count: +13
# 								* juv_other_count: +8
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/107 = 5.6% / MeanCost = 0.172):
# 						* juv_fel_count: +1
# 						* juv_misd_count: +1
# 						* juv_other_count: +8
# 						* priors_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (15/30 = 50.0% / MeanCost = 0.5):
# 						* juv_misd_count: +9
# 						* juv_other_count: +9
# 						* priors_count: +5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2460/2460 = 100.0% / MeanCost = 0.541):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# ##### Score:
# - Objective: 0.8010222468585053 => 0.8110218518710693
# - Update: True
# - Best: False
# - Time: 68.68031845600126
#
# Ckeckpoint !
# ### Iteration: 70
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If gender:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If race:Caucasian:
# 					- If age<35:
# 						- If priors_count<1:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/113 = 0.0% / MeanCost = 0.0707):
# 								* juv_fel_count: +2
# 								* juv_misd_count: +8
# 								* juv_other_count: +7
# 						- Else:
# 							- If age<29:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/33 = 0.0% / MeanCost = 0.0676):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +2
# 									* juv_other_count: +6
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/40 = 0.0% / MeanCost = 0.0699):
# 									* juv_fel_count: +1
# 									* juv_other_count: +8
# 					- Else:
# 						- If priors_count<1:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.589):
# 								* juv_other_count: +9
# 								* priors_count: +6
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							- If priors_count<5:
# 								- If age<45:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/74 = 2.7% / MeanCost = 0.168):
# 										* juv_misd_count: +7
# 										* juv_other_count: +7
# 										* priors_count: +2
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.107):
# 										* juv_other_count: +9
# 										* priors_count: +1
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (38/38 = 100.0% / MeanCost = 0.0608):
# 									* juv_other_count: +1
# 									* priors_count: +2
# 				- Else:
# 					- If age<35:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/35 = 0.0% / MeanCost = 0.0693):
# 								* juv_other_count: +5
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (37/306 = 12.1% / MeanCost = 0.0707):
# 								* juv_misd_count: +3
# 								* juv_other_count: +7
# 					- Else:
# 						- If race:African-American:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (110/250 = 44.0% / MeanCost = 0.134):
# 								* juv_misd_count: +1
# 								* juv_other_count: +9
# 								* priors_count: +1
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/117 = 0.0% / MeanCost = 0.0714):
# 								* juv_fel_count: +5
# 								* juv_misd_count: +12
# 								* juv_other_count: +9
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (848/848 = 100.0% / MeanCost = 0.543):
# 					* juv_fel_count: +1
# 					* juv_other_count: +6
# 					* priors_count: +10
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (683/683 = 100.0% / MeanCost = 0.578):
# 			* juv_misd_count: +1
# 			* juv_other_count: +4
# 			* priors_count: +12
#
# #### After "Insert"
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If gender:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If race:Caucasian:
# 					- If age<35:
# 						- If priors_count<1:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/113 = 0.0% / MeanCost = 0.0707):
# 								* juv_fel_count: +2
# 								* juv_misd_count: +8
# 								* juv_other_count: +7
# 						- Else:
# 							- If age<29:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/33 = 0.0% / MeanCost = 0.0676):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +2
# 									* juv_other_count: +6
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/40 = 0.0% / MeanCost = 0.0699):
# 									* juv_fel_count: +1
# 									* juv_other_count: +8
# 					- Else:
# 						- If priors_count<1:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.589):
# 								* juv_other_count: +9
# 								* priors_count: +6
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							- If priors_count<5:
# 								- If age<45:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/74 = 2.7% / MeanCost = 0.168):
# 										* juv_misd_count: +7
# 										* juv_other_count: +7
# 										* priors_count: +2
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.107):
# 										* juv_other_count: +9
# 										* priors_count: +1
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (38/38 = 100.0% / MeanCost = 0.0608):
# 									* juv_other_count: +1
# 									* priors_count: +2
# 				- Else:
# 					- If age<35:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/35 = 0.0% / MeanCost = 0.0693):
# 								* juv_other_count: +5
# 						- Else:
# 							- (+) If priors_count<5:
# 								* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (35/303 = 11.6% / MeanCost = 0.0707):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +3
# 									* juv_other_count: +7
# 							- Else:
# 								* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.0372):
# 									* priors_count: +1
# 					- Else:
# 						- If race:African-American:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (110/250 = 44.0% / MeanCost = 0.134):
# 								* juv_misd_count: +1
# 								* juv_other_count: +9
# 								* priors_count: +1
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/117 = 0.0% / MeanCost = 0.0714):
# 								* juv_fel_count: +5
# 								* juv_misd_count: +12
# 								* juv_other_count: +9
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (848/848 = 100.0% / MeanCost = 0.543):
# 					* juv_fel_count: +1
# 					* juv_other_count: +6
# 					* priors_count: +10
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (683/683 = 100.0% / MeanCost = 0.578):
# 			* juv_misd_count: +1
# 			* juv_other_count: +4
# 			* priors_count: +12
#
# ##### Score:
# - Objective: 0.8934587831047304 => 0.9030562770070535
# - Update: True
# - Best: False
# - Time: 95.07905127500271
#
# ### Iteration: 80
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If gender:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If race:Caucasian:
# 					- If age<35:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/31 = 0.0% / MeanCost = 0.0632):
# 								* juv_fel_count: +1
# 								* juv_other_count: +6
# 						- Else:
# 							- If age<29:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/78 = 0.0% / MeanCost = 0.0703):
# 									* juv_misd_count: +2
# 									* juv_other_count: +7
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/77 = 0.0% / MeanCost = 0.0709):
# 									* juv_fel_count: +3
# 									* juv_misd_count: +7
# 									* juv_other_count: +8
# 					- Else:
# 						- If priors_count<1:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.589):
# 								* juv_other_count: +9
# 								* priors_count: +6
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (21/93 = 22.6% / MeanCost = 0.148):
# 									* juv_misd_count: +7
# 									* juv_other_count: +7
# 									* priors_count: +2
# 							- Else:
# 								- If priors_count<5:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.107):
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/19 = 100.0% / MeanCost = 0.0573):
# 										* juv_other_count: +1
# 										* priors_count: +2
# 				- Else:
# 					- If age<35:
# 						- If age<24:
# 							- If priors_count<1:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/34 = 0.0% / MeanCost = 0.0707):
# 									* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0132):
# 									* juv_other_count: +1
# 						- Else:
# 							- If priors_count<5:
# 								- If priors_count<2:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/267 = 10.5% / MeanCost = 0.0707):
# 										* juv_fel_count: +1
# 										* juv_misd_count: +3
# 										* juv_other_count: +7
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/36 = 19.4% / MeanCost = 0.0693):
# 										* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.0372):
# 									* priors_count: +1
# 					- Else:
# 						- If race:African-American:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (110/250 = 44.0% / MeanCost = 0.134):
# 								* juv_misd_count: +1
# 								* juv_other_count: +9
# 								* priors_count: +1
# 						- Else:
# 							- If race:Hispanic:
# 								- If priors_count<1:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/23 = 0.0% / MeanCost = 0.552):
# 										* juv_misd_count: +8
# 										* juv_other_count: +9
# 										* priors_count: +5
# 								- Else:
# 									- If priors_count<2:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/21 = 0.0% / MeanCost = 0.0714):
# 											* juv_fel_count: +1
# 											* juv_misd_count: +2
# 											* juv_other_count: +9
# 									- Else:
# 										* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/19 = 0.0% / MeanCost = 0.0711):
# 											* juv_misd_count: +13
# 											* juv_other_count: +7
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/54 = 0.0% / MeanCost = 0.0714):
# 									* juv_fel_count: +4
# 									* juv_misd_count: +12
# 									* juv_other_count: +9
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (848/848 = 100.0% / MeanCost = 0.543):
# 					* juv_fel_count: +1
# 					* juv_other_count: +6
# 					* priors_count: +10
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (683/683 = 100.0% / MeanCost = 0.578):
# 			* juv_misd_count: +1
# 			* juv_other_count: +4
# 			* priors_count: +12
#
# #### After "Replace"
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If gender:
# 		- If age<96:
# 			- If c_charge_degree:F:
# 				- If race:Caucasian:
# 					- If age<35:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/31 = 0.0% / MeanCost = 0.0632):
# 								* juv_fel_count: +1
# 								* juv_other_count: +6
# 						- Else:
# 							- If age<29:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/78 = 0.0% / MeanCost = 0.0703):
# 									* juv_misd_count: +2
# 									* juv_other_count: +7
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/77 = 0.0% / MeanCost = 0.0709):
# 									* juv_fel_count: +3
# 									* juv_misd_count: +7
# 									* juv_other_count: +8
# 					- Else:
# 						- If priors_count<1:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.589):
# 								* juv_other_count: +9
# 								* priors_count: +6
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (21/93 = 22.6% / MeanCost = 0.148):
# 									* juv_misd_count: +7
# 									* juv_other_count: +7
# 									* priors_count: +2
# 							- Else:
# 								- If priors_count<5:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/98 = 0.0% / MeanCost = 0.107):
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/19 = 100.0% / MeanCost = 0.0573):
# 										* juv_other_count: +1
# 										* priors_count: +2
# 				- Else:
# 					- If age<35:
# 						- If age<24:
# 							- If priors_count<1:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/34 = 0.0% / MeanCost = 0.0707):
# 									* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0132):
# 									* juv_other_count: +1
# 						- Else:
# 							- If priors_count<5:
# 								- If priors_count<2:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/267 = 10.5% / MeanCost = 0.0707):
# 										* juv_fel_count: +1
# 										* juv_misd_count: +3
# 										* juv_other_count: +7
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/36 = 19.4% / MeanCost = 0.0693):
# 										* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.0372):
# 									* priors_count: +1
# 					- Else:
# 						- If race:African-American:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (110/250 = 44.0% / MeanCost = 0.134):
# 								* juv_misd_count: +1
# 								* juv_other_count: +9
# 								* priors_count: +1
# 						- Else:
# 							- If race:Hispanic:
# 								- (+) If age<45:
# 									* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/31 = 0.0% / MeanCost = 0.0714):
# 										* juv_fel_count: +1
# 										* juv_misd_count: +12
# 										* juv_other_count: +9
# 								- Else:
# 									- (+) If priors_count<2:
# 										* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/25 = 0.0% / MeanCost = 0.411):
# 											* juv_misd_count: +6
# 											* juv_other_count: +9
# 											* priors_count: +4
# 									- Else:
# 										* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0711):
# 											* juv_misd_count: +11
# 											* juv_other_count: +7
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/54 = 0.0% / MeanCost = 0.0714):
# 									* juv_fel_count: +4
# 									* juv_misd_count: +12
# 									* juv_other_count: +9
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (848/848 = 100.0% / MeanCost = 0.543):
# 					* juv_fel_count: +1
# 					* juv_other_count: +6
# 					* priors_count: +10
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 				* juv_misd_count: +13
# 				* juv_other_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (683/683 = 100.0% / MeanCost = 0.578):
# 			* juv_misd_count: +1
# 			* juv_other_count: +4
# 			* priors_count: +12
#
# ##### Score:
# - Objective: 0.9570775268491168 => 0.9561438649671669
# - Update: True
# - Best: False
# - Time: 102.85814013699928
#
# Ckeckpoint !
# ### Iteration: 90
# #### Before:
# - If race:Native American:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/3 = 100.0% / MeanCost = 0.56):
# 		* juv_misd_count: +13
# 		* juv_other_count: +9
# 		* priors_count: +9
# - Else:
# 	- If gender:
# 		- If age<96:
# 			- If c_charge_degree:M:
# 				- If race:Caucasian:
# 					- If age<35:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/16 = 0.0% / MeanCost = 0.0586):
# 								* juv_other_count: +4
# 						- Else:
# 							- If age<29:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/49 = 0.0% / MeanCost = 0.0705):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +5
# 									* juv_other_count: +8
# 							- Else:
# 								- If priors_count<5:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/57 = 0.0% / MeanCost = 0.0708):
# 										* juv_fel_count: +1
# 										* juv_misd_count: +5
# 										* juv_other_count: +8
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0504):
# 										* juv_other_count: +1
# 										* priors_count: +1
# 					- Else:
# 						- If age<45:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (25/84 = 29.8% / MeanCost = 0.425):
# 								* juv_other_count: +9
# 								* priors_count: +5
# 						- Else:
# 							- If priors_count<5:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (59/151 = 39.1% / MeanCost = 0.492):
# 									* juv_fel_count: +2
# 									* juv_other_count: +9
# 									* priors_count: +7
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (4/10 = 40.0% / MeanCost = 0.0677):
# 									* juv_other_count: +3
# 									* priors_count: +1
# 				- Else:
# 					- If age<35:
# 						- If age<24:
# 							- If race:Hispanic:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0707):
# 									* juv_fel_count: +8
# 									* juv_misd_count: +13
# 									* juv_other_count: +5
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/15 = 73.3% / MeanCost = 0.0709):
# 									* juv_other_count: +6
# 						- Else:
# 							- If priors_count<2:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (13/171 = 7.6% / MeanCost = 0.071):
# 									* juv_misd_count: +10
# 									* juv_other_count: +7
# 							- Else:
# 								- If race:Other:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.0677):
# 										* juv_misd_count: +11
# 										* juv_other_count: +3
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/33 = 33.3% / MeanCost = 0.0666):
# 										* juv_other_count: +8
# 					- Else:
# 						- If race:African-American:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (27/145 = 18.6% / MeanCost = 0.071):
# 								* juv_misd_count: +12
# 								* juv_other_count: +8
# 						- Else:
# 							- If race:Hispanic:
# 								- If age<45:
# 									- If priors_count<5:
# 										- If priors_count<1:
# 											* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/17 = 0.0% / MeanCost = 0.0714):
# 												* juv_fel_count: +8
# ...
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/12 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +4
# 										* juv_other_count: +9
# 										* priors_count: +1
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0711):
# 									* juv_other_count: +8
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (4/4 = 100.0% / MeanCost = 0.0504):
# 							* juv_fel_count: +5
# 							* juv_other_count: +1
# 							* priors_count: +1
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (379/379 = 100.0% / MeanCost = 0.567):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# #### After "Replace"
# - If gender:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2010/2054 = 97.9% / MeanCost = 0.492):
# 		* juv_misd_count: +3
# 		* juv_other_count: +6
# 		* priors_count: +8
# - Else:
# 	- If race:Caucasian:
# 		- If c_charge_degree:M:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (164/164 = 100.0% / MeanCost = 0.6):
# 				* juv_misd_count: +1
# 				* juv_other_count: +5
# 				* priors_count: +11
# 		- Else:
# 			- If priors_count<1:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (63/63 = 100.0% / MeanCost = 0.646):
# 					* juv_fel_count: +3
# 					* juv_other_count: +7
# 					* priors_count: +8
# 			- Else:
# 				- If age<29:
# 					- (+) If age<24:
# 						- (+) If priors_count<2:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/3 = 0.0% / MeanCost = 0.0701):
# 								* juv_fel_count: +8
# 								* juv_misd_count: +3
# 								* juv_other_count: +4
# 						- Else:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0335):
# 								* juv_fel_count: +8
# 					- Else:
# 						- (+) If priors_count<2:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/7 = 0.0% / MeanCost = 0.0711):
# 								* juv_other_count: +8
# 						- Else:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/6 = 50.0% / MeanCost = 0.0504):
# 								* juv_other_count: +1
# 				- Else:
# 					- If priors_count<5:
# 						- If age<35:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/15 = 20.0% / MeanCost = 0.113):
# 								* juv_fel_count: +3
# 								* juv_other_count: +8
# 								* priors_count: +1
# 						- Else:
# 							- If priors_count<2:
# 								- If age<45:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +13
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/12 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +4
# 										* juv_other_count: +9
# 										* priors_count: +1
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/24 = 0.0% / MeanCost = 0.0711):
# 									* juv_other_count: +8
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (4/4 = 100.0% / MeanCost = 0.0504):
# 							* juv_fel_count: +5
# 							* juv_other_count: +1
# 							* priors_count: +1
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (379/379 = 100.0% / MeanCost = 0.567):
# 			* juv_misd_count: +2
# 			* juv_other_count: +4
# 			* priors_count: +11
#
# ##### Score:
# - Objective: 0.6713546869824165 => 0.6713546869824165
# - Update: True
# - Best: False
# - Time: 852.6766802940001
#
# Ckeckpoint !
# ### Iteration: 490
# #### Before:
# - If gender:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2010/2054 = 97.9% / MeanCost = 0.492):
# 		* juv_misd_count: +3
# 		* juv_other_count: +6
# 		* priors_count: +8
# - Else:
# 	- If c_charge_degree:M:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (328/328 = 100.0% / MeanCost = 0.613):
# 			* juv_other_count: +4
# 			* priors_count: +12
# 	- Else:
# 		- If priors_count<1:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (164/164 = 100.0% / MeanCost = 0.646):
# 				* juv_fel_count: +3
# 				* juv_other_count: +7
# 				* priors_count: +8
# 		- Else:
# 			- If age<29:
# 				- If age<24:
# 					- If priors_count<2:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/12 = 8.3% / MeanCost = 0.0709):
# 							* juv_other_count: +6
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/2 = 100.0% / MeanCost = 0.0504):
# 							* juv_fel_count: +1
# 							* juv_other_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/34 = 0.0% / MeanCost = 0.0714):
# 						* juv_other_count: +9
# 			- Else:
# 				- If priors_count<5:
# 					- If age<35:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/30 = 6.7% / MeanCost = 0.0695):
# 							* juv_fel_count: +1
# 							* juv_other_count: +8
# 					- Else:
# 						- If priors_count<2:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/17 = 0.0% / MeanCost = 0.0714):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/25 = 0.0% / MeanCost = 0.139):
# 									* juv_misd_count: +1
# 									* juv_other_count: +9
# 									* priors_count: +1
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/31 = 29.0% / MeanCost = 0.0777):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 									* priors_count: +1
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/22 = 9.1% / MeanCost = 0.0711):
# 									* juv_fel_count: +1
# 									* juv_other_count: +8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (18/18 = 100.0% / MeanCost = 0.0678):
# 						* juv_other_count: +3
# 						* priors_count: +2
#
# #### After "Insert"
# - If gender:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2010/2054 = 97.9% / MeanCost = 0.492):
# 		* juv_misd_count: +3
# 		* juv_other_count: +6
# 		* priors_count: +8
# - Else:
# 	- If c_charge_degree:M:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (328/328 = 100.0% / MeanCost = 0.613):
# 			* juv_other_count: +4
# 			* priors_count: +12
# 	- Else:
# 		- If priors_count<1:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (164/164 = 100.0% / MeanCost = 0.646):
# 				* juv_fel_count: +3
# 				* juv_other_count: +7
# 				* priors_count: +8
# 		- Else:
# 			- If age<29:
# 				- If age<24:
# 					- If priors_count<2:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/12 = 8.3% / MeanCost = 0.0709):
# 							* juv_other_count: +6
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/2 = 100.0% / MeanCost = 0.0504):
# 							* juv_fel_count: +1
# 							* juv_other_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/34 = 0.0% / MeanCost = 0.0714):
# 						* juv_other_count: +9
# 			- Else:
# 				- If priors_count<5:
# 					- If age<35:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/30 = 6.7% / MeanCost = 0.0695):
# 							* juv_fel_count: +1
# 							* juv_other_count: +8
# 					- Else:
# 						- If priors_count<2:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/17 = 0.0% / MeanCost = 0.0714):
# 									* juv_fel_count: +1
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 							- Else:
# 								- (+) If race:African-American:
# 									* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/10 = 0.0% / MeanCost = 0.139):
# 										* juv_fel_count: +1
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/15 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +3
# 										* juv_other_count: +9
# 										* priors_count: +1
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/31 = 29.0% / MeanCost = 0.0777):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 									* priors_count: +1
# 							- Else:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/22 = 9.1% / MeanCost = 0.0711):
# 									* juv_fel_count: +1
# 									* juv_other_count: +8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (18/18 = 100.0% / MeanCost = 0.0678):
# 						* juv_other_count: +3
# 						* priors_count: +2
#
# ##### Score:
# - Objective: 0.6800403708530804 => 0.6900403708530805
# - Update: True
# - Best: False
# - Time: 857.3085889790018
#
# ### Iteration: 500
# #### Before:
# - If gender:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2010/2054 = 97.9% / MeanCost = 0.492):
# 		* juv_misd_count: +3
# 		* juv_other_count: +6
# 		* priors_count: +8
# - Else:
# 	- If c_charge_degree:M:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (328/328 = 100.0% / MeanCost = 0.613):
# 			* juv_other_count: +4
# 			* priors_count: +12
# 	- Else:
# 		- If priors_count<1:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (164/164 = 100.0% / MeanCost = 0.646):
# 				* juv_fel_count: +3
# 				* juv_other_count: +7
# 				* priors_count: +8
# 		- Else:
# 			- If age<29:
# 				- If age<24:
# 					- If priors_count<2:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/12 = 8.3% / MeanCost = 0.0709):
# 							* juv_other_count: +6
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/2 = 100.0% / MeanCost = 0.0504):
# 							* juv_fel_count: +1
# 							* juv_other_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/34 = 0.0% / MeanCost = 0.0714):
# 						* juv_other_count: +9
# 			- Else:
# 				- If priors_count<5:
# 					- If age<35:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/30 = 6.7% / MeanCost = 0.0695):
# 							* juv_fel_count: +1
# 							* juv_other_count: +8
# 					- Else:
# 						- If priors_count<2:
# 							- If age<45:
# 								- If race:Caucasian:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +13
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/12 = 0.0% / MeanCost = 0.0714):
# 										* juv_fel_count: +1
# 										* juv_other_count: +9
# 							- Else:
# 								- If race:African-American:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/10 = 0.0% / MeanCost = 0.139):
# 										* juv_fel_count: +1
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/15 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +3
# 										* juv_other_count: +9
# 										* priors_count: +1
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/31 = 29.0% / MeanCost = 0.0777):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 									* priors_count: +1
# 							- Else:
# 								- If race:Caucasian:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/11 = 0.0% / MeanCost = 0.0709):
# 										* juv_misd_count: +1
# 										* juv_other_count: +6
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/11 = 18.2% / MeanCost = 0.0709):
# 										* juv_fel_count: +1
# 										* juv_other_count: +6
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (18/18 = 100.0% / MeanCost = 0.0678):
# 						* juv_other_count: +3
# 						* priors_count: +2
#
# #### After "Insert"
# - If gender:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2010/2054 = 97.9% / MeanCost = 0.492):
# 		* juv_misd_count: +3
# 		* juv_other_count: +6
# 		* priors_count: +8
# - Else:
# 	- If c_charge_degree:M:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (328/328 = 100.0% / MeanCost = 0.613):
# 			* juv_other_count: +4
# 			* priors_count: +12
# 	- Else:
# 		- If priors_count<1:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (164/164 = 100.0% / MeanCost = 0.646):
# 				* juv_fel_count: +3
# 				* juv_other_count: +7
# 				* priors_count: +8
# 		- Else:
# 			- If age<29:
# 				- If age<24:
# 					- If priors_count<2:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/12 = 8.3% / MeanCost = 0.0709):
# 							* juv_other_count: +6
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/2 = 100.0% / MeanCost = 0.0504):
# 							* juv_fel_count: +1
# 							* juv_other_count: +1
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/34 = 0.0% / MeanCost = 0.0714):
# 						* juv_other_count: +9
# 			- Else:
# 				- If priors_count<5:
# 					- If age<35:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/30 = 6.7% / MeanCost = 0.0695):
# 							* juv_fel_count: +1
# 							* juv_other_count: +8
# 					- Else:
# 						- If priors_count<2:
# 							- If age<45:
# 								- If race:Caucasian:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/5 = 0.0% / MeanCost = 0.139):
# 										* juv_misd_count: +13
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/12 = 0.0% / MeanCost = 0.0714):
# 										* juv_fel_count: +1
# 										* juv_other_count: +9
# 							- Else:
# 								- If race:African-American:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/10 = 0.0% / MeanCost = 0.139):
# 										* juv_fel_count: +1
# 										* juv_other_count: +9
# 										* priors_count: +1
# 								- Else:
# 									- (+) If race:Other:
# 										* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0707):
# 											* juv_fel_count: +8
# 											* juv_other_count: +5
# 									- Else:
# 										* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/14 = 0.0% / MeanCost = 0.139):
# 											* juv_misd_count: +3
# 											* juv_other_count: +9
# 											* priors_count: +1
# 						- Else:
# 							- If age<45:
# 								* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/31 = 29.0% / MeanCost = 0.0777):
# 									* juv_misd_count: +6
# 									* juv_other_count: +9
# 									* priors_count: +1
# 							- Else:
# 								- If race:Caucasian:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/11 = 0.0% / MeanCost = 0.0709):
# 										* juv_misd_count: +1
# 										* juv_other_count: +6
# 								- Else:
# 									* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/11 = 18.2% / MeanCost = 0.0709):
# 										* juv_fel_count: +1
# 										* juv_other_count: +6
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (18/18 = 100.0% / MeanCost = 0.0678):
# 						* juv_other_count: +3
# 						* priors_count: +2
#
# ##### Score:
# - Objective: 0.7101624488072458 => 0.7201374486350075
# - Update: False
# - Best: False
# - Time: 871.154548759001
#
# Ckeckpoint !
# * Parameters:
# 	* lambda: 0.01
# 	* gamma: 1.0
# 	* max_iteration: 500
# 	* leaf size bound: 101
# 	* leaf size: 2
# 	* LIME approximation: True
# 	* Time[s]: 871.154848041002
#
# ### Learned CET
# - If age<35:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1237/1237 = 100.0% / MeanCost = 0.525):
# 		* juv_misd_count: +1
# 		* juv_other_count: +4
# 		* priors_count: +7
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1456/1500 = 97.1% / MeanCost = 0.458):
# 		* juv_other_count: +7
# 		* priors_count: +8

# %%
x_cet = cet.predict(X_vl) + X_vl
y_cet = mdl.predict(x_cet)

print('Negative accuracy of CET = {}'.format(np.mean(y_cet != mdl.predict(X_vl))))
print('Negative Oulier CET = {}'.format(np.mean(isolation.predict(x_cet) == -1)))
# Out:
# Negative accuracy of CET = 0.9847161572052402
# Negative Oulier CET = 1.0

# %%
print('Sparsity', np.mean(np.sum(x_cet-X_vl!=0, axis=1)))
# Out:
# Sparsity 2.4716157205240177
