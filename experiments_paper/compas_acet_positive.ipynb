# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from utils import MyTabNetClassifier
from acv_explainers.utils import *
from ares import AReS
from cet import CounterfactualExplanationTree
from ce import ActionExtractor
from utils import DatasetHelper, submodular_picking, DATASETS_NAME
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

seed = 2022
np.random.seed(0)

# %%
# Load Compas dataset

seed = 2022
np.random.seed(0)

dataset = 'c'
dataset_name = DATASETS_NAME[dataset]
model= 'X'

LAMBDA = 0.01
GAMMA = 1.0

D = DatasetHelper(dataset=dataset, feature_prefix_index=False)
X_tr, X_ts, y_tr, y_ts = D.train_test_split()

# %%
# Train Isolation for outlier score

from sklearn.ensemble import IsolationForest

isolation = IsolationForest()
isolation.fit(X_tr)
# Out:
# IsolationForest()

# %%
# Train the model to explain

mdl = LGBMClassifier(n_estimators=50, num_leaves=8)
mdl.fit(X_tr, y_tr)
# Out:
# LGBMClassifier(n_estimators=50, num_leaves=8)

# %%
D.feature_names
# Out:
# ['age',
#  'juv_fel_count',
#  'juv_misd_count',
#  'juv_other_count',
#  'priors_count',
#  'race:African-American',
#  'race:Asian',
#  'race:Caucasian',
#  'race:Hispanic',
#  'race:Native American',
#  'race:Other',
#  'c_charge_degree:F',
#  'c_charge_degree:M',
#  'gender']

# %%
D.target_name
# Out:
# 'RecidivateWithinTwoYears'

# %%
D.feature_constraints
# Out:
# ['INC',
#  '',
#  '',
#  '',
#  '',
#  'FIX',
#  'FIX',
#  'FIX',
#  'FIX',
#  'FIX',
#  'FIX',
#  '',
#  '',
#  'FIX']

# %%
D.feature_categories
# Out:
# [[5, 6, 7, 8, 9, 10], [11, 12]]

# %%
D.feature_types
# Out:
# ['I', 'I', 'I', 'I', 'I', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B']

# %%
X = X_tr[mdl.predict(X_tr)==1]
X_vl = X_ts[mdl.predict(X_ts)==1]

# %% [markdown]
# ## Actionable Recourse Summary

# %%
print('## Actionable Recourse Summary')
ares = AReS(mdl, X_tr, max_rule=4, max_rule_length=4, discretization_bins=10, minimum_support=0.05, print_objective=False,
            feature_names=D.feature_names, feature_types=D.feature_types, feature_categories=D.feature_categories, 
            feature_constraints=D.feature_constraints, target_name=D.target_name, target_labels=D.target_labels)
ares = ares.fit(X, max_change_num=4, cost_type='MPS', lambda_acc=1.0, lambda_cov=1.0, lambda_cst=1.0)
print('* Parameters:')
print('\t* lambda_acc: {}'.format(ares.lambda_acc)); print('\t* lambda_cov: {}'.format(ares.lambda_cov)); print('\t* lambda_cst: {}'.format(ares.lambda_cst));
print('\t* minimum support: {}'.format(ares.rule_miner_.minsup_)); print('\t* discretization bins: {}'.format(ares.rule_miner_.fd_.bins)); print('\t* pre-processing time[s]: {}'.format(ares.preprocess_time_)); 
print('\t* max rule: {}'.format(ares.max_rule_)); print('\t* max rule length: {}'.format(ares.max_rule_length_)); print('\t* Time[s]:', ares.time_); 
print('\t* uncover test: {}'.format(ares.uncover(X_vl))); print('\t* conflict: {}'.format(ares.conflict(X_vl))); print();
print('### Learned AReS')
print(ares.to_markdown())
# Out:
# ## Actionable Recourse Summary
# * Parameters:
# 	* lambda_acc: 1.0
# 	* lambda_cov: 1.0
# 	* lambda_cst: 1.0
# 	* minimum support: 0.05
# 	* discretization bins: 10
# 	* pre-processing time[s]: 0.6413756720030506
# 	* max rule: 4
# 	* max rule length: 4
# 	* Time[s]: 183.13370283599943
# 	* uncover test: 0.3354632587859425
# 	* conflict: 0.016826923076923076
#
# ### Learned AReS
# | | Rule | Action |
# | :---: | --- | --- |
# | Recourse <br> rule 1 <br> (probability: 19.7%) | If 'juv_fel_count<1' <br> AND '6<=priors_count<10' | juv_fel_count<1 <br> AND priors_count<1 |
# | Recourse <br> rule 2 <br> (probability: 18.2%) | If 'priors_count>=10' <br> AND 'gender=True' | priors_count<1 <br> AND gender=True |
# | Recourse <br> rule 3 <br> (probability: 15.8%) | If 'age<22' <br> AND 'juv_fel_count<1' | 47<=age<53 <br> AND juv_fel_count<1 |
# | Recourse <br> rule 4 <br> (probability: 12.7%) | If '22<=age<24' <br> AND 'juv_fel_count<1' | age>=53 |
# | Default <br> rule | Else | priors_count<1 <br> AND gender=False |

# %%
x_ares = ares.predict(X_vl) + X_vl
y_ares = mdl.predict(x_ares)

print('Positive accuracy of AReS = {}'.format(np.mean(y_ares != mdl.predict(X_vl))))
print('Positive Inlier AReS = {}'.format(np.mean(isolation.predict(x_ares) == 1)))
# Out:
# Positive accuracy of AReS = 0.9808306709265175
# Positive Inlier AReS = 0.8003194888178914

# %%
print('Sparsity', np.mean(np.sum(x_ares-X_vl!=0, axis=1)))
# Out:
# Sparsity 1.0

# %% [markdown]
# # Counterfactual TREE

# %%
print('## Counterfactual Explanation Tree')
cet = CounterfactualExplanationTree(mdl, X_tr, y_tr, max_iteration=500, lime_approximation=(model!='L'),
                                    feature_names=D.feature_names, feature_types=D.feature_types, feature_categories=D.feature_categories,
                                    feature_constraints=D.feature_constraints, target_name=D.target_name, target_labels=D.target_labels)

cet = cet.fit(X, max_change_num=8, cost_type='MPS', C=LAMBDA, gamma=GAMMA, max_leaf_size=-1, time_limit=180, verbose=True)
print('* Parameters:'); print('\t* lambda: {}'.format(cet.lambda_)); print('\t* gamma: {}'.format(cet.gamma_)); print('\t* max_iteration: {}'.format(cet.max_iteration_));
print('\t* leaf size bound:', cet.leaf_size_bound_); print('\t* leaf size:', cet.n_leaves_); print('\t* LIME approximation:', cet.lime_approximation_); print('\t* Time[s]:', cet.time_); print();
print('### Learned CET')
cet.print_tree()
# Out:
# ## Counterfactual Explanation Tree
# ## Stochastic Local Searching ...
# ### Iteration: 10
# #### Before:
# - If age<35:
# 	- If race:Other:
# 		- If c_charge_degree:M:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (13/14 = 92.9% / MeanCost = 0.342):
# 				* age: +10
# 				* juv_fel_count: +2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (31/36 = 86.1% / MeanCost = 0.557):
# 				* age: +21
# 				* juv_misd_count: +4
# 				* c_charge_degree: "F" -> "M"
# 	- Else:
# 		- If juv_fel_count<8:
# 			- If race:Asian:
# 				- If age<29:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/4 = 75.0% / MeanCost = 0.337):
# 						* age: +9
# 						* juv_fel_count: +8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0962):
# 						* age: +3
# 						* priors_count: -2
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1166/1459 = 79.9% / MeanCost = 0.724):
# 					* age: +62
# 					* juv_fel_count: +1
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 				* age: +20
# 				* juv_fel_count: -8
# 				* juv_misd_count: +13
# 				* juv_other_count: -1
# 				* priors_count: -14
# 				* c_charge_degree: "F" -> "M"
# - Else:
# 	- If race:Native American:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.184):
# 			* age: +30
# 			* juv_misd_count: +13
# 			* priors_count: -10
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (184/371 = 49.6% / MeanCost = 0.21):
# 			* age: +26
# 			* juv_fel_count: +1
# 			* juv_misd_count: +4
# 			* priors_count: -3
#
# #### After "Insert"
# - If age<35:
# 	- If race:Other:
# 		- If c_charge_degree:M:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (13/14 = 92.9% / MeanCost = 0.342):
# 				* age: +10
# 				* juv_fel_count: +2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (31/36 = 86.1% / MeanCost = 0.557):
# 				* age: +21
# 				* juv_misd_count: +4
# 				* c_charge_degree: "F" -> "M"
# 	- Else:
# 		- If juv_fel_count<8:
# 			- If race:Asian:
# 				- If age<29:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (3/4 = 75.0% / MeanCost = 0.337):
# 						* age: +9
# 						* juv_fel_count: +8
# 				- Else:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0962):
# 						* age: +3
# 						* priors_count: -2
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1166/1459 = 79.9% / MeanCost = 0.724):
# 					* age: +62
# 					* juv_fel_count: +1
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 				* age: +20
# 				* juv_fel_count: -8
# 				* juv_misd_count: +13
# 				* juv_other_count: -1
# 				* priors_count: -14
# 				* c_charge_degree: "F" -> "M"
# - Else:
# 	- If race:Native American:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.184):
# 			* age: +30
# 			* juv_misd_count: +13
# 			* priors_count: -10
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (184/371 = 49.6% / MeanCost = 0.21):
# 			* age: +26
# 			* juv_fel_count: +1
# 			* juv_misd_count: +4
# 			* priors_count: -3
#
# ##### Score:
# - Objective: 0.9544788640411117 => 0.9544788640411117
# - Update: True
# - Best: False
# - Time: 19.74552885599769
#
# ### Iteration: 20
# #### Before:
# - If age<35:
# 	- If race:Other:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (42/50 = 84.0% / MeanCost = 0.526):
# 			* age: +19
# 	- Else:
# 		- If race:Hispanic:
# 			- If age<29:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/67 = 35.8% / MeanCost = 0.0408):
# 					* age: +1
# 					* juv_fel_count: +6
# 			- Else:
# 				- If c_charge_degree:M:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/5 = 100.0% / MeanCost = 0.19):
# 						* age: +6
# 						* juv_fel_count: +2
# 						* juv_misd_count: +13
# 						* priors_count: -2
# 				- Else:
# 					- If priors_count<5:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/2 = 100.0% / MeanCost = 0.0892):
# 							* age: +2
# 							* juv_misd_count: +13
# 							* priors_count: -1
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (4/10 = 40.0% / MeanCost = 0.473):
# 							* age: +34
# 							* juv_fel_count: +2
# 							* juv_misd_count: +12
# 							* priors_count: -4
# 							* c_charge_degree: "F" -> "M"
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1096/1381 = 79.4% / MeanCost = 0.722):
# 				* age: +62
# - Else:
# 	- If race:Native American:
# 		- If gender:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 				* age: +13
# 				* juv_fel_count: -4
# 				* juv_misd_count: +13
# 				* priors_count: -14
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 				* age: +9
# 				* juv_other_count: +1
# 				* priors_count: -8
# 	- Else:
# 		- If race:Other:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.148):
# 				* age: +13
# 				* juv_fel_count: +6
# 				* juv_misd_count: +12
# 				* priors_count: -3
# 		- Else:
# 			- If gender:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (153/318 = 48.1% / MeanCost = 0.207):
# 					* age: +26
# 					* juv_fel_count: +2
# 					* juv_misd_count: +6
# 					* priors_count: -3
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/42 = 57.1% / MeanCost = 0.24):
# 					* age: +30
# 					* juv_misd_count: +11
# 					* priors_count: -3
#
# #### After "Replace"
# - If age<35:
# 	- If race:Other:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (42/50 = 84.0% / MeanCost = 0.526):
# 			* age: +19
# 	- Else:
# 		- If race:Hispanic:
# 			- If age<29:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/67 = 35.8% / MeanCost = 0.0408):
# 					* age: +1
# 					* juv_fel_count: +6
# 			- Else:
# 				- If c_charge_degree:M:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/5 = 100.0% / MeanCost = 0.19):
# 						* age: +6
# 						* juv_fel_count: +2
# 						* juv_misd_count: +13
# 						* priors_count: -2
# 				- Else:
# 					- (+) If priors_count<5:
# 						* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/2 = 100.0% / MeanCost = 0.0892):
# 							* age: +2
# 							* juv_misd_count: +13
# 							* priors_count: -1
# 					- Else:
# 						* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (4/10 = 40.0% / MeanCost = 0.473):
# 							* age: +34
# 							* juv_fel_count: +2
# 							* juv_misd_count: +12
# 							* priors_count: -4
# 							* c_charge_degree: "F" -> "M"
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1096/1381 = 79.4% / MeanCost = 0.722):
# 				* age: +62
# - Else:
# 	- If race:Native American:
# 		- If gender:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 				* age: +13
# 				* juv_fel_count: -4
# 				* juv_misd_count: +13
# 				* priors_count: -14
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 				* age: +9
# 				* juv_other_count: +1
# 				* priors_count: -8
# 	- Else:
# 		- If race:Other:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.148):
# 				* age: +13
# 				* juv_fel_count: +6
# 				* juv_misd_count: +12
# 				* priors_count: -3
# 		- Else:
# 			- If gender:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (153/318 = 48.1% / MeanCost = 0.207):
# 					* age: +26
# 					* juv_fel_count: +2
# 					* juv_misd_count: +6
# 					* priors_count: -3
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/42 = 57.1% / MeanCost = 0.24):
# 					* age: +30
# 					* juv_misd_count: +11
# 					* priors_count: -3
#
# ##### Score:
# - Objective: 0.9795785669754389 => 0.9795785669754389
# - Update: True
# - Best: False
# - Time: 36.60341563799739
#
# Ckeckpoint !
# ### Iteration: 30
# #### Before:
# - If age<35:
# 	- If race:Other:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (42/50 = 84.0% / MeanCost = 0.526):
# 			* age: +19
# 	- Else:
# 		- If race:Hispanic:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (27/28 = 96.4% / MeanCost = 0.0807):
# 					* age: +2
# 			- Else:
# 				- If c_charge_degree:M:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/10 = 90.0% / MeanCost = 0.295):
# 						* age: +10
# 						* priors_count: -2
# 				- Else:
# 					- If priors_count<5:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/28 = 100.0% / MeanCost = 0.372):
# 							* age: +10
# 							* priors_count: -2
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/18 = 61.1% / MeanCost = 0.563):
# 							* age: +35
# 							* juv_misd_count: +9
# 							* priors_count: -4
# 							* c_charge_degree: "F" -> "M"
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1096/1381 = 79.4% / MeanCost = 0.722):
# 				* age: +62
# - Else:
# 	- If race:Native American:
# 		- If gender:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 				* age: +13
# 				* juv_fel_count: -4
# 				* juv_misd_count: +13
# 				* priors_count: -14
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 				* age: +9
# 				* juv_other_count: +1
# 				* priors_count: -8
# 	- Else:
# 		- If priors_count<5:
# 			- If c_charge_degree:M:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.00649):
# 					* juv_other_count: +2
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0288):
# 					* age: +1
# 					* juv_fel_count: +2
# 		- Else:
# 			- If gender:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (201/327 = 61.5% / MeanCost = 0.222):
# 					* age: +26
# 					* juv_misd_count: +7
# 					* priors_count: -5
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/42 = 66.7% / MeanCost = 0.262):
# 					* age: +30
# 					* juv_fel_count: +2
# 					* juv_misd_count: +11
# 					* priors_count: -5
#
# #### After "Replace"
# - If age<35:
# 	- If race:Other:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (42/50 = 84.0% / MeanCost = 0.526):
# 			* age: +19
# 	- Else:
# 		- If race:Hispanic:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (27/28 = 96.4% / MeanCost = 0.0807):
# 					* age: +2
# 			- Else:
# 				- If c_charge_degree:M:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/10 = 90.0% / MeanCost = 0.295):
# 						* age: +10
# 						* priors_count: -2
# 				- Else:
# 					- If priors_count<5:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/28 = 100.0% / MeanCost = 0.372):
# 							* age: +10
# 							* priors_count: -2
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/18 = 61.1% / MeanCost = 0.563):
# 							* age: +35
# 							* juv_misd_count: +9
# 							* priors_count: -4
# 							* c_charge_degree: "F" -> "M"
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1096/1381 = 79.4% / MeanCost = 0.722):
# 				* age: +62
# - Else:
# 	- If race:Native American:
# 		- If gender:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 				* age: +13
# 				* juv_fel_count: -4
# 				* juv_misd_count: +13
# 				* priors_count: -14
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 				* age: +9
# 				* juv_other_count: +1
# 				* priors_count: -8
# 	- Else:
# 		- (+) If race:Caucasian:
# 			- (+) If c_charge_degree:M:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/16 = 43.8% / MeanCost = 0.161):
# 					* age: +30
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/58 = 67.2% / MeanCost = 0.198):
# 					* age: +25
# 					* juv_fel_count: +2
# 					* juv_misd_count: +3
# 					* priors_count: -3
# 		- Else:
# 			- (+) If gender:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (120/267 = 44.9% / MeanCost = 0.211):
# 					* age: +27
# 					* juv_fel_count: +2
# 					* juv_misd_count: +7
# 					* priors_count: -3
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/30 = 63.3% / MeanCost = 0.283):
# 					* age: +30
# 					* juv_fel_count: +2
# 					* juv_misd_count: +11
# 					* priors_count: -5
#
# ##### Score:
# - Objective: 0.9557833622196543 => 0.9771373837512578
# - Update: True
# - Best: False
# - Time: 40.659737259000394
#
# ### Iteration: 40
# #### Before:
# - If juv_misd_count<13:
# 	- If race:Caucasian:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (312/427 = 73.1% / MeanCost = 0.537):
# 			* age: +26
# 			* juv_misd_count: +5
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (943/1460 = 64.6% / MeanCost = 0.537):
# 			* age: +27
# 			* juv_misd_count: +1
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.741):
# 		* age: +45
# 		* juv_fel_count: +8
# 		* juv_other_count: -1
# 		* priors_count: -20
# 		* c_charge_degree: "F" -> "M"
#
# #### After "Insert"
# - If juv_misd_count<13:
# 	- If race:Caucasian:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (312/427 = 73.1% / MeanCost = 0.537):
# 			* age: +26
# 			* juv_misd_count: +5
# 	- Else:
# 		- (+) If age<24:
# 			* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (431/451 = 95.6% / MeanCost = 0.719):
# 				* age: +25
# 				* juv_fel_count: +1
# 		- Else:
# 			* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (584/1009 = 57.9% / MeanCost = 0.443):
# 				* age: +27
# 				* juv_misd_count: +1
# 				* priors_count: -1
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.741):
# 		* age: +45
# 		* juv_fel_count: +8
# 		* juv_other_count: -1
# 		* priors_count: -20
# 		* c_charge_degree: "F" -> "M"
#
# ##### Score:
# - Objective: 0.9019383054925478 => 0.8673848371028743
# - Update: True
# - Best: False
# - Time: 65.61370821699893
#
# Ckeckpoint !
# ### Iteration: 50
# #### Before:
# - If age<35:
# 	- If race:Caucasian:
# 		- If priors_count<1:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (47/47 = 100.0% / MeanCost = 0.478):
# 				* age: +12
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (260/306 = 85.0% / MeanCost = 0.6):
# 				* age: +27
# 				* juv_fel_count: +1
# 				* juv_misd_count: +10
# 				* priors_count: -1
# 	- Else:
# 		- If priors_count<2:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (303/303 = 100.0% / MeanCost = 0.442):
# 				* age: +11
# 		- Else:
# 			- If race:Hispanic:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/56 = 80.4% / MeanCost = 0.328):
# 					* age: +10
# 					* priors_count: -2
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (642/803 = 80.0% / MeanCost = 0.658):
# 					* age: +62
# 					* priors_count: -2
# - Else:
# 	- If race:Caucasian:
# 		- If c_charge_degree:M:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/16 = 43.8% / MeanCost = 0.161):
# 				* age: +30
# 				* juv_misd_count: +12
# 				* priors_count: -2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/58 = 67.2% / MeanCost = 0.198):
# 				* age: +25
# 				* juv_fel_count: +2
# 				* juv_misd_count: +3
# 				* priors_count: -3
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (135/299 = 45.2% / MeanCost = 0.216):
# 			* age: +27
# 			* juv_fel_count: +1
# 			* juv_misd_count: +7
# 			* priors_count: -3
#
# #### After "Replace"
# - If age<35:
# 	- If race:Caucasian:
# 		- If priors_count<1:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (47/47 = 100.0% / MeanCost = 0.478):
# 				* age: +12
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (260/306 = 85.0% / MeanCost = 0.6):
# 				* age: +27
# 				* juv_fel_count: +1
# 				* juv_misd_count: +10
# 				* priors_count: -1
# 	- Else:
# 		- (+) If race:Hispanic:
# 			* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (841/1078 = 78.0% / MeanCost = 0.721):
# 				* age: +62
# - Else:
# 	- If race:Caucasian:
# 		- If c_charge_degree:M:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/16 = 43.8% / MeanCost = 0.161):
# 				* age: +30
# 				* juv_misd_count: +12
# 				* priors_count: -2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/58 = 67.2% / MeanCost = 0.198):
# 				* age: +25
# 				* juv_fel_count: +2
# 				* juv_misd_count: +3
# 				* priors_count: -3
# 	- Else:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (135/299 = 45.2% / MeanCost = 0.216):
# 			* age: +27
# 			* juv_fel_count: +1
# 			* juv_misd_count: +7
# 			* priors_count: -3
#
# ##### Score:
# - Objective: 0.8086027737672337 => 0.9114750994919039
# - Update: True
# - Best: False
# - Time: 87.57126992399935
#
# ### Iteration: 60
# #### Before:
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (56/70 = 80.0% / MeanCost = 0.507):
# 					* age: +48
# 					* juv_misd_count: +11
# 					* priors_count: -3
# 					* c_charge_degree: "F" -> "M"
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If priors_count<2:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (303/303 = 100.0% / MeanCost = 0.442):
# 				* age: +11
# 		- Else:
# 			- If race:Hispanic:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/56 = 80.4% / MeanCost = 0.328):
# 					* age: +10
# 					* priors_count: -2
# 			- Else:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/34 = 82.4% / MeanCost = 0.269):
# 						* age: +8
# 						* juv_fel_count: +4
# 						* juv_misd_count: +4
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (610/769 = 79.3% / MeanCost = 0.658):
# 						* age: +62
# 						* priors_count: -2
# - Else:
# 	- If priors_count<5:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.0288):
# 			* age: +1
# 			* juv_fel_count: +2
# 	- Else:
# 		- If race:Other:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.148):
# 				* age: +13
# 				* juv_fel_count: +6
# 				* juv_misd_count: +12
# 				* priors_count: -3
# 		- Else:
# 			- If race:Native American:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 						* age: +13
# 						* juv_fel_count: -4
# 						* juv_misd_count: +13
# 						* priors_count: -14
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 						* age: +9
# 						* juv_other_count: +1
# 						* priors_count: -8
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (222/358 = 62.0% / MeanCost = 0.225):
# 					* age: +26
# 					* juv_misd_count: +7
# 					* priors_count: -5
#
# #### After "Replace"
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- (+) If c_charge_degree:F:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (56/70 = 80.0% / MeanCost = 0.507):
# 					* age: +48
# 					* juv_misd_count: +11
# 					* priors_count: -3
# 					* c_charge_degree: "F" -> "M"
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If priors_count<2:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (303/303 = 100.0% / MeanCost = 0.442):
# 				* age: +11
# 		- Else:
# 			- If race:Hispanic:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/56 = 80.4% / MeanCost = 0.328):
# 					* age: +10
# 					* priors_count: -2
# 			- Else:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (28/34 = 82.4% / MeanCost = 0.269):
# 						* age: +8
# 						* juv_fel_count: +4
# 						* juv_misd_count: +4
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (610/769 = 79.3% / MeanCost = 0.658):
# 						* age: +62
# 						* priors_count: -2
# - Else:
# 	- If priors_count<5:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.0288):
# 			* age: +1
# 			* juv_fel_count: +2
# 	- Else:
# 		- If race:Other:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.148):
# 				* age: +13
# 				* juv_fel_count: +6
# 				* juv_misd_count: +12
# 				* priors_count: -3
# 		- Else:
# 			- If race:Native American:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 						* age: +13
# 						* juv_fel_count: -4
# 						* juv_misd_count: +13
# 						* priors_count: -14
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 						* age: +9
# 						* juv_other_count: +1
# 						* priors_count: -8
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (222/358 = 62.0% / MeanCost = 0.225):
# 					* age: +26
# 					* juv_misd_count: +7
# 					* priors_count: -5
#
# ##### Score:
# - Objective: 0.81703687543503 => 0.81703687543503
# - Update: True
# - Best: False
# - Time: 97.12989647499853
#
# Ckeckpoint !
# ### Iteration: 70
# #### Before:
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (10/13 = 76.9% / MeanCost = 0.407):
# 						* age: +19
# 						* juv_fel_count: +5
# 						* juv_misd_count: +12
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (841/1078 = 78.0% / MeanCost = 0.721):
# 				* age: +62
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:F:
# 			- If race:African-American:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (69/111 = 62.2% / MeanCost = 0.324):
# 					* age: +52
# 					* juv_misd_count: +10
# 					* priors_count: -5
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/41 = 58.5% / MeanCost = 0.309):
# 					* age: +47
# 					* juv_misd_count: +7
# 					* priors_count: -2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/42 = 45.2% / MeanCost = 0.298):
# 				* age: +47
# 				* juv_fel_count: +3
# 				* juv_misd_count: +8
# 				* priors_count: -2
# 	- Else:
# 		- If race:African-American:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (54/122 = 44.3% / MeanCost = 0.12):
# 				* age: +27
# 				* juv_fel_count: +2
# 				* juv_misd_count: +5
# 				* priors_count: -4
# 		- Else:
# 			- If race:Native American:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 						* age: +13
# 						* juv_fel_count: -4
# 						* juv_misd_count: +13
# 						* priors_count: -14
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 						* age: +9
# 						* juv_other_count: +1
# 						* priors_count: -8
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (34/55 = 61.8% / MeanCost = 0.126):
# 					* age: +26
# 					* priors_count: -4
#
# #### After "Replace"
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (10/13 = 76.9% / MeanCost = 0.407):
# 						* age: +19
# 						* juv_fel_count: +5
# 						* juv_misd_count: +12
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (841/1078 = 78.0% / MeanCost = 0.721):
# 				* age: +62
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:F:
# 			- (+) If race:African-American:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (69/111 = 62.2% / MeanCost = 0.324):
# 					* age: +52
# 					* juv_misd_count: +10
# 					* priors_count: -5
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/41 = 58.5% / MeanCost = 0.309):
# 					* age: +47
# 					* juv_misd_count: +7
# 					* priors_count: -2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/42 = 45.2% / MeanCost = 0.298):
# 				* age: +47
# 				* juv_fel_count: +3
# 				* juv_misd_count: +8
# 				* priors_count: -2
# 	- Else:
# 		- If race:African-American:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (54/122 = 44.3% / MeanCost = 0.12):
# 				* age: +27
# 				* juv_fel_count: +2
# 				* juv_misd_count: +5
# 				* priors_count: -4
# 		- Else:
# 			- If race:Native American:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.139):
# 						* age: +13
# 						* juv_fel_count: -4
# 						* juv_misd_count: +13
# 						* priors_count: -14
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.118):
# 						* age: +9
# 						* juv_other_count: +1
# 						* priors_count: -8
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (34/55 = 61.8% / MeanCost = 0.126):
# 					* age: +26
# 					* priors_count: -4
#
# ##### Score:
# - Objective: 0.9600619427882011 => 0.9600619427882011
# - Update: True
# - Best: False
# - Time: 109.73995775900039
#
# ### Iteration: 80
# #### Before:
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (10/13 = 76.9% / MeanCost = 0.407):
# 						* age: +19
# 						* juv_fel_count: +5
# 						* juv_misd_count: +12
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			- If c_charge_degree:M:
# 				- If race:Asian:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0962):
# 						* age: +3
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (207/255 = 81.2% / MeanCost = 0.71):
# 						* age: +52
# 						* juv_misd_count: +7
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (634/822 = 77.1% / MeanCost = 0.725):
# 					* age: +62
# 					* c_charge_degree: "F" -> "M"
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:M:
# 			- If race:African-American:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (16/35 = 45.7% / MeanCost = 0.302):
# 					* age: +47
# 					* juv_fel_count: +2
# 					* juv_misd_count: +8
# 					* priors_count: -2
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/7 = 71.4% / MeanCost = 0.264):
# 					* age: +25
# 					* juv_misd_count: +13
# 					* priors_count: -5
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (84/152 = 55.3% / MeanCost = 0.316):
# 				* age: +52
# 				* juv_misd_count: +6
# 				* priors_count: -3
# 	- Else:
# 		- If race:Native American:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.184):
# 				* age: +30
# 				* juv_misd_count: +13
# 				* priors_count: -10
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If race:African-American:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/91 = 42.9% / MeanCost = 0.117):
# 						* age: +30
# 						* juv_fel_count: +1
# 						* juv_misd_count: +5
# 						* priors_count: -4
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (26/44 = 59.1% / MeanCost = 0.129):
# 						* age: +24
# 						* juv_fel_count: +1
# 						* priors_count: -4
# 			- Else:
# 				- If race:African-American:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/31 = 35.5% / MeanCost = 0.114):
# 						* age: +25
# 						* juv_fel_count: +1
# 						* priors_count: -3
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.101):
# 						* age: +29
# 						* priors_count: -2
#
# #### After "Insert"
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (10/13 = 76.9% / MeanCost = 0.407):
# 						* age: +19
# 						* juv_fel_count: +5
# 						* juv_misd_count: +12
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			- If c_charge_degree:M:
# 				- If race:Asian:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0962):
# 						* age: +3
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (207/255 = 81.2% / MeanCost = 0.71):
# 						* age: +52
# 						* juv_misd_count: +7
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (634/822 = 77.1% / MeanCost = 0.725):
# 					* age: +62
# 					* c_charge_degree: "F" -> "M"
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:M:
# 			- If race:African-American:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (16/35 = 45.7% / MeanCost = 0.302):
# 					* age: +47
# 					* juv_fel_count: +2
# 					* juv_misd_count: +8
# 					* priors_count: -2
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/7 = 71.4% / MeanCost = 0.264):
# 					* age: +25
# 					* juv_misd_count: +13
# 					* priors_count: -5
# 		- Else:
# 			- (+) If race:Hispanic:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/9 = 77.8% / MeanCost = 0.317):
# 					* age: +26
# 					* juv_fel_count: +5
# 					* juv_misd_count: +12
# 					* priors_count: -5
# 			- Else:
# 				* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (78/143 = 54.5% / MeanCost = 0.315):
# 					* age: +52
# 					* juv_misd_count: +6
# 					* priors_count: -3
# 	- Else:
# 		- If race:Native American:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.184):
# 				* age: +30
# 				* juv_misd_count: +13
# 				* priors_count: -10
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If race:African-American:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/91 = 42.9% / MeanCost = 0.117):
# 						* age: +30
# 						* juv_fel_count: +1
# 						* juv_misd_count: +5
# 						* priors_count: -4
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (26/44 = 59.1% / MeanCost = 0.129):
# 						* age: +24
# 						* juv_fel_count: +1
# 						* priors_count: -4
# 			- Else:
# 				- If race:African-American:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/31 = 35.5% / MeanCost = 0.114):
# 						* age: +25
# 						* juv_fel_count: +1
# 						* priors_count: -3
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.101):
# 						* age: +29
# 						* priors_count: -2
#
# ##### Score:
# - Objective: 0.9954924521438889 => 1.0048754874745973
# - Update: True
# - Best: False
# - Time: 123.10351538599934
#
# Ckeckpoint !
# ### Iteration: 90
# #### Before:
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					- If priors_count<5:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/5 = 100.0% / MeanCost = 0.178):
# 							* age: +6
# 							* juv_fel_count: +5
# 							* juv_misd_count: +6
# 							* priors_count: -1
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/8 = 62.5% / MeanCost = 0.369):
# 							* age: +18
# 							* juv_fel_count: +6
# 							* juv_misd_count: +12
# 							* priors_count: -4
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			- If c_charge_degree:M:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (13/14 = 92.9% / MeanCost = 0.342):
# 						* age: +10
# 						* juv_fel_count: +2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (194/242 = 80.2% / MeanCost = 0.708):
# 						* age: +52
# 						* juv_misd_count: +7
# 			- Else:
# 				- If age<29:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (521/607 = 85.8% / MeanCost = 0.804):
# 						* age: +68
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (136/215 = 63.3% / MeanCost = 0.5):
# 						* age: +62
# 						* juv_misd_count: +1
# 						* priors_count: -2
# 						* c_charge_degree: "F" -> "M"
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:M:
# 			- If race:Caucasian:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (4/6 = 66.7% / MeanCost = 0.253):
# 					* age: +25
# 					* juv_misd_count: +13
# 					* priors_count: -5
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (17/36 = 47.2% / MeanCost = 0.304):
# 					* age: +47
# 					* juv_fel_count: +2
# 					* juv_misd_count: +8
# 					* priors_count: -2
# 		- Else:
# 			- If race:Hispanic:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/9 = 77.8% / MeanCost = 0.317):
# 					* age: +26
# 					* juv_fel_count: +5
# 					* juv_misd_count: +12
# 					* priors_count: -5
# 			- Else:
# 				- If priors_count<5:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0288):
# 						* age: +1
# 						* juv_fel_count: +2
# 				- Else:
# 					- If race:Caucasian:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (21/26 = 80.8% / MeanCost = 0.284):
# 							* age: +25
# 							* juv_fel_count: +2
# 							* juv_misd_count: +7
# 							* priors_count: -4
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (73/116 = 62.9% / MeanCost = 0.325):
# 							* age: +52
# 							* juv_fel_count: +1
# 							* juv_misd_count: +10
# 							* priors_count: -5
# 	- Else:
# 		- If race:Native American:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.184):
# 				* age: +30
# 				* juv_misd_count: +13
# 				* priors_count: -10
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If race:African-American:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/91 = 42.9% / MeanCost = 0.117):
# 						* age: +30
# 						* juv_fel_count: +1
# 						* juv_misd_count: +5
# 						* priors_count: -4
# 				- Else:
# 					- If race:Other:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/5 = 40.0% / MeanCost = 0.0871):
# 							* age: +11
# 							* juv_fel_count: +8
# 							* juv_misd_count: +13
# 							* priors_count: -3
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/39 = 61.5% / MeanCost = 0.132):
# 							* age: +24
# 							* juv_fel_count: +1
# 							* priors_count: -4
# 			- Else:
# 				- If race:African-American:
# 					- If gender:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/29 = 37.9% / MeanCost = 0.111):
# 							* age: +25
# 							* juv_fel_count: +1
# 							* priors_count: -3
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.158):
# 							* age: +33
# 							* juv_misd_count: +12
# 							* priors_count: -8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.101):
# 						* age: +29
# 						* priors_count: -2
#
# #### After "Delete"
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					- If priors_count<5:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/5 = 100.0% / MeanCost = 0.178):
# 							* age: +6
# 							* juv_fel_count: +5
# 							* juv_misd_count: +6
# 							* priors_count: -1
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/8 = 62.5% / MeanCost = 0.369):
# 							* age: +18
# 							* juv_fel_count: +6
# 							* juv_misd_count: +12
# 							* priors_count: -4
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (72/84 = 85.7% / MeanCost = 0.471):
# 				* age: +15
# 				* juv_fel_count: +2
# 		- Else:
# 			- If c_charge_degree:M:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (13/14 = 92.9% / MeanCost = 0.342):
# 						* age: +10
# 						* juv_fel_count: +2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (194/242 = 80.2% / MeanCost = 0.708):
# 						* age: +52
# 						* juv_misd_count: +7
# 			- Else:
# 				- If age<29:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (521/607 = 85.8% / MeanCost = 0.804):
# 						* age: +68
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (136/215 = 63.3% / MeanCost = 0.5):
# 						* age: +62
# 						* juv_misd_count: +1
# 						* priors_count: -2
# 						* c_charge_degree: "F" -> "M"
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:M:
# 			* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/42 = 45.2% / MeanCost = 0.298):
# 				* age: +47
# 				* juv_fel_count: +3
# 				* juv_misd_count: +8
# 				* priors_count: -2
# 		- Else:
# 			- If race:Hispanic:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (7/9 = 77.8% / MeanCost = 0.317):
# 					* age: +26
# 					* juv_fel_count: +5
# 					* juv_misd_count: +12
# 					* priors_count: -5
# 			- Else:
# 				- If priors_count<5:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0288):
# 						* age: +1
# 						* juv_fel_count: +2
# 				- Else:
# 					- If race:Caucasian:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (21/26 = 80.8% / MeanCost = 0.284):
# 							* age: +25
# 							* juv_fel_count: +2
# 							* juv_misd_count: +7
# 							* priors_count: -4
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (73/116 = 62.9% / MeanCost = 0.325):
# 							* age: +52
# 							* juv_fel_count: +1
# 							* juv_misd_count: +10
# 							* priors_count: -5
# 	- Else:
# 		- If race:Native American:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.184):
# 				* age: +30
# 				* juv_misd_count: +13
# 				* priors_count: -10
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If race:African-American:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (39/91 = 42.9% / MeanCost = 0.117):
# 						* age: +30
# 						* juv_fel_count: +1
# 						* juv_misd_count: +5
# 						* priors_count: -4
# 				- Else:
# 					- If race:Other:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/5 = 40.0% / MeanCost = 0.0871):
# 							* age: +11
# 							* juv_fel_count: +8
# 							* juv_misd_count: +13
# 							* priors_count: -3
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (24/39 = 61.5% / MeanCost = 0.132):
# 							* age: +24
# 							* juv_fel_count: +1
# 							* priors_count: -4
# 			- Else:
# 				- If race:African-American:
# 					- If gender:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (11/29 = 37.9% / MeanCost = 0.111):
# 							* age: +25
# 							* juv_fel_count: +1
# 							* priors_count: -3
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.158):
# 							* age: +33
# 							* juv_misd_count: +12
# 							* priors_count: -8
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (6/11 = 54.5% / MeanCost = 0.101):
# 						* age: +29
# 						* priors_count: -2
#
# ##### Score:
# - Objective: 1.0396747138216211 => 1.0307726377312645
# - Update: True
# - Best: False
# - Time: 129.0569679839973
#
# ### Iteration: 100
# #### Before:
# - If age<35:
# 	- If race:Caucasian:
# 		- If age<29:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (225/258 = 87.2% / MeanCost = 0.586):
# 				* age: +20
# 		- Else:
# 			- If c_charge_degree:F:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (45/57 = 78.9% / MeanCost = 0.502):
# 						* age: +48
# 						* juv_misd_count: +11
# 						* priors_count: -3
# 						* c_charge_degree: "F" -> "M"
# 				- Else:
# 					- If priors_count<5:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/5 = 100.0% / MeanCost = 0.178):
# 							* age: +6
# 							* juv_fel_count: +5
# 							* juv_misd_count: +6
# 							* priors_count: -1
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (5/8 = 62.5% / MeanCost = 0.369):
# 							* age: +18
# 							* juv_fel_count: +6
# 							* juv_misd_count: +12
# 							* priors_count: -4
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/25 = 92.0% / MeanCost = 0.407):
# 					* age: +22
# 					* juv_fel_count: +6
# 					* juv_misd_count: +12
# 					* priors_count: -2
# 	- Else:
# 		- If race:Hispanic:
# 			- If priors_count<1:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (14/18 = 77.8% / MeanCost = 0.038):
# 					* age: +1
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (54/66 = 81.8% / MeanCost = 0.387):
# 					* age: +12
# 					* priors_count: -1
# 		- Else:
# 			- If priors_count<2:
# 				- If race:Other:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (16/16 = 100.0% / MeanCost = 0.447):
# 						* age: +11
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (259/259 = 100.0% / MeanCost = 0.442):
# 						* age: +11
# 			- Else:
# 				- If age<29:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (455/519 = 87.7% / MeanCost = 0.744):
# 						* age: +68
# 						* priors_count: -2
# 				- Else:
# 					- If race:Asian:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0962):
# 							* age: +3
# 							* priors_count: -2
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (186/283 = 65.7% / MeanCost = 0.501):
# 							* age: +62
# 							* juv_misd_count: +1
# 							* priors_count: -2
# - Else:
# 	- If age<45:
# 		- If c_charge_degree:M:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (19/42 = 45.2% / MeanCost = 0.298):
# 				* age: +47
# 				* juv_fel_count: +3
# 				* juv_misd_count: +8
# 				* priors_count: -2
# 		- Else:
# 			- If race:Other:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (2/4 = 50.0% / MeanCost = 0.0258):
# 						* juv_fel_count: +5
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0288):
# 						* age: +1
# 						* juv_fel_count: +2
# 			- Else:
# 				- If priors_count<5:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0288):
# 						* age: +1
# 						* juv_fel_count: +2
# 				- Else:
# 					- If race:Caucasian:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (21/26 = 80.8% / MeanCost = 0.284):
# 							* age: +25
# 							* juv_fel_count: +2
# 							* juv_misd_count: +7
# 							* priors_count: -4
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (76/120 = 63.3% / MeanCost = 0.325):
# 							* age: +52
# ...
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				- If age<35:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (527/528 = 99.8% / MeanCost = 0.451):
# 						* age: +15
# 						* priors_count: -2
# 				- Else:
# 					- (+) If gender:
# 						* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.00649):
# 							* juv_other_count: +2
# 					- Else:
# 						* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.0288):
# 							* age: +1
# 							* juv_fel_count: +2
# 		- Else:
# 			- If race:Asian:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.104):
# 					* age: +3
# 					* juv_fel_count: +8
# 					* priors_count: -2
# 			- Else:
# 				- If c_charge_degree:F:
# 					- If race:African-American:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (378/535 = 70.7% / MeanCost = 0.437):
# 							* age: +30
# 							* juv_fel_count: +2
# 							* priors_count: -5
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/9 = 100.0% / MeanCost = 0.5):
# 								* age: +12
# 								* juv_misd_count: +5
# 								* priors_count: -5
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (160/200 = 80.0% / MeanCost = 0.395):
# 								* age: +26
# 								* juv_fel_count: +2
# 								* juv_misd_count: +7
# 								* priors_count: -5
# 				- Else:
# 					- If race:African-American:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (116/164 = 70.7% / MeanCost = 0.415):
# 							* age: +27
# 							* juv_fel_count: +1
# 							* juv_misd_count: +7
# 							* priors_count: -5
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (55/61 = 90.2% / MeanCost = 0.389):
# 							* age: +20
# 							* juv_fel_count: +2
# 							* juv_misd_count: +7
# 							* priors_count: -5
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# ##### Score:
# - Objective: 0.637941900329623 => 0.637941900329623
# - Update: True
# - Best: False
# - Time: 538.953455789997
# ### Iteration: 480
# #### Before:
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (451/452 = 99.8% / MeanCost = 0.452):
# 						* age: +15
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (78/78 = 100.0% / MeanCost = 0.339):
# 						* age: +10
# 						* priors_count: -2
# 		- Else:
# 			- If race:Asian:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.104):
# 					* age: +3
# 					* juv_fel_count: +8
# 					* priors_count: -2
# 			- Else:
# 				- If c_charge_degree:F:
# 					- If race:African-American:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (378/535 = 70.7% / MeanCost = 0.437):
# 							* age: +30
# 							* juv_fel_count: +2
# 							* priors_count: -5
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/9 = 100.0% / MeanCost = 0.5):
# 								* age: +12
# 								* juv_misd_count: +5
# 								* priors_count: -5
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (160/200 = 80.0% / MeanCost = 0.395):
# 								* age: +26
# 								* juv_fel_count: +2
# 								* juv_misd_count: +7
# 								* priors_count: -5
# 				- Else:
# 					- If race:African-American:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (116/164 = 70.7% / MeanCost = 0.415):
# 							* age: +27
# 							* juv_fel_count: +1
# 							* juv_misd_count: +7
# 							* priors_count: -5
# 					- Else:
# 						- If age<29:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (22/22 = 100.0% / MeanCost = 0.63):
# 								* age: +28
# 								* priors_count: -5
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (33/39 = 84.6% / MeanCost = 0.298):
# 								* age: +22
# 								* juv_fel_count: +1
# 								* juv_misd_count: +7
# 								* priors_count: -4
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# #### After "Insert"
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (451/452 = 99.8% / MeanCost = 0.452):
# 						* age: +15
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (78/78 = 100.0% / MeanCost = 0.339):
# 						* age: +10
# 						* priors_count: -2
# 		- Else:
# 			- If race:Asian:
# 				- (+) If age<29:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0399):
# 						* age: +1
# 						* juv_fel_count: +8
# 						* priors_count: -1
# 				- Else:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (0/1 = 0.0% / MeanCost = 0.0962):
# 						* age: +3
# 						* priors_count: -2
# 			- Else:
# 				- If c_charge_degree:F:
# 					- If race:African-American:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (378/535 = 70.7% / MeanCost = 0.437):
# 							* age: +30
# 							* juv_fel_count: +2
# 							* priors_count: -5
# 					- Else:
# 						- If age<24:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (9/9 = 100.0% / MeanCost = 0.5):
# 								* age: +12
# 								* juv_misd_count: +5
# 								* priors_count: -5
# 								* c_charge_degree: "F" -> "M"
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (160/200 = 80.0% / MeanCost = 0.395):
# 								* age: +26
# 								* juv_fel_count: +2
# 								* juv_misd_count: +7
# 								* priors_count: -5
# 				- Else:
# 					- If race:African-American:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (116/164 = 70.7% / MeanCost = 0.415):
# 							* age: +27
# 							* juv_fel_count: +1
# 							* juv_misd_count: +7
# 							* priors_count: -5
# 					- Else:
# 						- If age<29:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (22/22 = 100.0% / MeanCost = 0.63):
# 								* age: +28
# 								* priors_count: -5
# 						- Else:
# 							* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (33/39 = 84.6% / MeanCost = 0.298):
# 								* age: +22
# 								* juv_fel_count: +1
# 								* juv_misd_count: +7
# 								* priors_count: -4
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# ##### Score:
# - Objective: 0.6343614060043238 => 0.6448530284148644
# - Update: True
# - Best: False
# - Time: 567.1316878259968
#
# Ckeckpoint !
# ### Iteration: 490
# #### Before:
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (529/530 = 99.8% / MeanCost = 0.45):
# 					* age: +15
# 					* priors_count: -2
# 		- Else:
# 			- If age<24:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (29/32 = 90.6% / MeanCost = 0.672):
# 					* age: +23
# 					* juv_fel_count: +4
# 					* juv_misd_count: +5
# 					* priors_count: -5
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (673/939 = 71.7% / MeanCost = 0.404):
# 					* age: +26
# 					* priors_count: -5
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# #### After "Insert"
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (529/530 = 99.8% / MeanCost = 0.45):
# 					* age: +15
# 					* priors_count: -2
# 		- Else:
# 			- If age<24:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (29/32 = 90.6% / MeanCost = 0.672):
# 					* age: +23
# 					* juv_fel_count: +4
# 					* juv_misd_count: +5
# 					* priors_count: -5
# 			- Else:
# 				- (+) If race:Hispanic:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (27/41 = 65.9% / MeanCost = 0.428):
# 						* age: +38
# 						* juv_fel_count: +6
# 						* juv_misd_count: +9
# 						* priors_count: -4
# 				- Else:
# 					* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (644/898 = 71.7% / MeanCost = 0.404):
# 						* age: +26
# 						* priors_count: -5
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# ##### Score:
# - Objective: 0.5819633302715774 => 0.5937440210432245
# - Update: False
# - Best: False
# - Time: 599.275400020997
#
# ### Iteration: 500
# #### Before:
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (529/530 = 99.8% / MeanCost = 0.45):
# 					* age: +15
# 					* priors_count: -2
# 		- Else:
# 			- If age<24:
# 				- If race:Caucasian:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (8/8 = 100.0% / MeanCost = 0.509):
# 						* age: +14
# 						* juv_fel_count: +1
# 						* juv_misd_count: +5
# 						* priors_count: -4
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/24 = 95.8% / MeanCost = 0.871):
# 						* age: +58
# 						* juv_misd_count: +5
# 						* priors_count: -5
# 			- Else:
# 				- If race:Hispanic:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (27/41 = 65.9% / MeanCost = 0.428):
# 						* age: +38
# 						* juv_fel_count: +6
# 						* juv_misd_count: +9
# 						* priors_count: -4
# 				- Else:
# 					- If race:Asian:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.104):
# 							* age: +3
# 							* juv_fel_count: +8
# 							* priors_count: -2
# 					- Else:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (642/896 = 71.7% / MeanCost = 0.404):
# 							* age: +26
# 							* priors_count: -5
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# #### After "Insert"
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (529/530 = 99.8% / MeanCost = 0.45):
# 					* age: +15
# 					* priors_count: -2
# 		- Else:
# 			- If age<24:
# 				- If race:Caucasian:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (8/8 = 100.0% / MeanCost = 0.509):
# 						* age: +14
# 						* juv_fel_count: +1
# 						* juv_misd_count: +5
# 						* priors_count: -4
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (23/24 = 95.8% / MeanCost = 0.871):
# 						* age: +58
# 						* juv_misd_count: +5
# 						* priors_count: -5
# 			- Else:
# 				- If race:Hispanic:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (27/41 = 65.9% / MeanCost = 0.428):
# 						* age: +38
# 						* juv_fel_count: +6
# 						* juv_misd_count: +9
# 						* priors_count: -4
# 				- Else:
# 					- If race:Asian:
# 						* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/2 = 50.0% / MeanCost = 0.104):
# 							* age: +3
# 							* juv_fel_count: +8
# 							* priors_count: -2
# 					- Else:
# 						- (+) If c_charge_degree:F:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (484/681 = 71.1% / MeanCost = 0.402):
# 								* age: +26
# 								* juv_fel_count: +1
# 								* priors_count: -5
# 						- Else:
# 							* (+) Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (162/215 = 75.3% / MeanCost = 0.397):
# 								* age: +24
# 								* juv_fel_count: +2
# 								* juv_misd_count: +5
# 								* priors_count: -5
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"
#
# ##### Score:
# - Objective: 0.614626154063925 => 0.621115541972673
# - Update: False
# - Best: False
# - Time: 626.6814156619985
#
# Ckeckpoint !
# * Parameters:
# 	* lambda: 0.01
# 	* gamma: 1.0
# 	* max_iteration: 500
# 	* leaf size bound: 101
# 	* leaf size: 6
# 	* LIME approximation: True
# 	* Time[s]: 626.6814680759999
#
# ### Learned CET
# - If juv_fel_count<8:
# 	- If priors_count<1:
# 		* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (205/209 = 98.1% / MeanCost = 0.124):
# 			* age: +3
# 	- Else:
# 		- If priors_count<5:
# 			- If priors_count<2:
# 				* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (177/177 = 100.0% / MeanCost = 0.259):
# 					* age: +6
# 					* priors_count: -1
# 			- Else:
# 				- If gender:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (451/452 = 99.8% / MeanCost = 0.452):
# 						* age: +15
# 						* priors_count: -2
# 				- Else:
# 					* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (78/78 = 100.0% / MeanCost = 0.339):
# 						* age: +10
# 						* priors_count: -2
# 		- Else:
# 			* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (700/971 = 72.1% / MeanCost = 0.414):
# 				* age: +26
# 				* priors_count: -5
# - Else:
# 	* Action [RecidivateWithinTwoYears: Recidivate -> NotRecidivate] (1/1 = 100.0% / MeanCost = 0.455):
# 		* age: +20
# 		* juv_fel_count: -8
# 		* juv_misd_count: +13
# 		* juv_other_count: -1
# 		* priors_count: -14
# 		* c_charge_degree: "F" -> "M"

# %%
x_cet = cet.predict(X_vl) + X_vl
y_cet = mdl.predict(x_cet)

print('Positive accuracy of CET = {}'.format(np.mean(y_cet != mdl.predict(X_vl))))
print('Positive INlier CET = {}'.format(np.mean(isolation.predict(x_cet) == 1)))
# Out:
# Positive accuracy of CET = 0.8594249201277955
# Positive INlier CET = 0.694888178913738

# %%
print('sparsity', np.mean(np.sum(x_cet-X_vl!=0, axis=1)))
# Out:
# sparsity 1.8961661341853036

# %%
cet.print_tree()
# Out:
# - If Glucose<108:
# 	* Action [Diabetes: Bad -> Good] (409/409 = 100.0% / MeanCost = 0.682):
# 		* Pregnancies: +2
# 		* Glucose: +54
# 		* SkinThickness: +28
# 		* BMI: +33.8520
# 		* DiabetesPedigreeFunction: +0.4684
# 		* Age: +13
# - Else:
# 	- If SkinThickness<35:
# 		- If BMI<33.7:
# 			* Action [Diabetes: Bad -> Good] (241/243 = 99.2% / MeanCost = 0.703):
# 				* Pregnancies: +3
# 				* Glucose: +5
# 				* SkinThickness: +19
# 				* BMI: +48.3600
# 				* DiabetesPedigreeFunction: +0.4076
# 		- Else:
# 			* Action [Diabetes: Bad -> Good] (56/56 = 100.0% / MeanCost = 0.23):
# 				* Glucose: +16
# 				* BloodPressure: -2
# 				* SkinThickness: +3
# 				* BMI: +35.6160
# 				* DiabetesPedigreeFunction: +0.0368
# 				* Age: +2
# 	- Else:
# 		* Action [Diabetes: Bad -> Good] (70/70 = 100.0% / MeanCost = 0.251):
# 			* Glucose: +11
# 			* BloodPressure: -3
# 			* SkinThickness: +42
# 			* BMI: +23.4240
# 			* DiabetesPedigreeFunction: +0.0248
# 			* Age: +1
